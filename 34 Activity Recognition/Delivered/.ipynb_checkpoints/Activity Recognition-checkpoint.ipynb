# %% [markdown]
# ## import libraries

# %% [markdown]
# - stop displaying of warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# - import libraries

# %%
import pandas as pd
import glob
import os

import re
import string
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics
import math

from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report, accuracy_score,precision_score, recall_score, f1_score

pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# ## Read Data
#
# - read dataset that we join in the last file
# - display first 20 samples for demo purpose

# %%
df = pd.read_csv("data/balance_df.csv")

print("\n\nSample Data:")
print("============\n")
print(df.head(20))
# Out:
# Sample Data:
# ============
#
#         C1  C2    C3       C4        C5        C6       C7        C8  \
# 0   245.60   1   NaN  31.2500  8.454240 -1.871440  4.59909  8.451590
# 1   141.46   1   NaN  31.1875  0.618133  5.846740  7.95803  0.448719
# 2   130.66   1   NaN  32.6250  4.859850  0.239379  8.34838  5.033420
# 3   217.70   1   NaN  30.8750  0.483315  4.564340  8.69159  0.458395
# 4   194.22   1   NaN  33.3750  5.079910 -0.142770  8.23750  5.193740
# 5   356.67   1   NaN  31.4375  7.083600  1.801560  6.79844  7.035430
# 6    97.33   1   NaN  30.2500  0.335643  4.111920  8.88335  0.291327
# 7   148.52   1   NaN  33.6875  6.801130  2.859530  6.05938  7.071460
# 8   134.71   1   NaN  33.3125  4.966010 -0.407134  8.27518  5.087230
# 9   101.13   1   NaN  33.5625  7.179290  3.273280  5.98667  7.331990
# 10  134.08   1  72.0  33.9375  6.531090 -1.911720  6.87966  6.510870
# 11  156.96   1   NaN  30.5625  0.406670  4.413170  8.69096  0.398364
# 12  205.88   1   NaN  33.3750  4.996580 -0.295621  8.04433  5.118260
# 13  170.04   1   NaN  33.3125  4.886150 -0.256135  8.11952  5.177280
# 14  229.15   1   NaN  30.9375  0.405062  4.564260  8.61345  0.444092
# 15  212.67   1   NaN  33.3750  4.960660 -0.219115  8.08202  5.222370
# 16  148.06   1   NaN  34.7500  0.647155  7.008510  6.37656  0.901705
# 17  221.97   1   NaN  33.7500  6.766020  2.481770  6.21408  7.130200
# 18  201.32   1   NaN  31.1250  8.501110 -1.528600  4.79107  8.423730
# 19   76.53   1   NaN  33.5000  7.054970  2.665450  5.79442  7.175180
#
#           C9      C10       C11       C12       C13       C14        C15  \
# 0  -1.821780  4.83646 -0.003862  0.035060 -0.012050  -1.03899  16.916200
# 1   5.790110  8.01423  0.030756 -0.002772 -0.011148 -32.48750  16.656500
# 2   0.169734  8.62589 -0.024254  0.003839 -0.009147  20.10590   6.975220
# 3   4.476780  8.69664 -0.018941 -0.023570 -0.005784  -5.51657  16.420900
# 4  -0.390293  8.53635  0.007873 -0.011045 -0.023413  13.94960  24.435600
# 5   1.693990  6.77821 -0.026709  0.003748 -0.010853   7.72662   3.198920
# 6   4.085550  8.93928 -0.000609 -0.001130 -0.022368  -5.04381  18.133100
# 7   2.856170  6.30750 -0.028849  0.021544 -0.001115   6.71883  -0.123135
# 8  -0.540518  8.56699 -0.032415 -0.009630 -0.007181  15.19830  23.748700
# 9   3.503560  6.16991 -0.104496  0.008530 -0.030097   6.92718  -1.871590
# 13 -2.86641  0.025555  0.012336  0.021881 -17.0654  26.3031  -4.92288
# 14 -4.75586  0.020158 -0.021035  0.000285 -13.0727  29.8334  -6.33125
# 15 -2.80610  0.027521 -0.028098 -0.025757 -16.3115  26.7801  -5.06261
# 16 -3.84953  0.001792 -0.011203  0.020810 -14.3106  28.4815  -5.48304
# 17 -3.41051 -0.009000 -0.028714  0.019042 -12.5548  23.3767  -4.03286
# 18  1.09589  0.041662 -0.017397  0.030310 -15.8852  18.6969  -8.38779
# 19 -2.89414 -0.006807 -0.014815  0.033357 -12.6688  23.1682  -4.65304
#
#          C51       C52       C53       C54
# 0   0.165813  0.107752  0.653892 -0.730289
# 1   1.000000  0.000000  0.000000  0.000000
# 2   0.261371  0.091206  0.610883 -0.741747
# 3   0.185934  0.404819  0.751988 -0.485864
# 4   0.184019  0.252370  0.759455 -0.570680
# 5   0.172975  0.168926  0.734595 -0.633967
# 6   0.193156  0.400549  0.742325 -0.501204
# 7   0.185575  0.301629  0.764891 -0.538074
# 8   0.181246  0.248547  0.758521 -0.574474
# 9   0.185301  0.293029  0.753166 -0.559051
# 10  0.223397 -0.462934 -0.811710 -0.277331
# 11  0.186796  0.399533  0.746701 -0.497914
# 12  0.184772  0.249841  0.759222 -0.571857
# 13  0.181627  0.247140  0.759944 -0.573079
# 14  0.183068  0.406054  0.753565 -0.483473
# 15  0.182705  0.247890  0.758694 -0.574067
# 16  0.200520  0.342867  0.755083 -0.521616
# 17  0.182604  0.302587  0.760475 -0.544770
# 18  0.166804  0.109590  0.652139 -0.731356
# 19  0.188118  0.282720  0.743431 -0.576187

# %% [markdown]
# ## Utils Function
# - count-digit funtion calculat the count of digit in a number (like 100 have the 3 digits)
# - the purpose of above function is to just for displaying the equal sign qual to the leangth of digits.
#
# - check-shape function count the number of rows and columns in the dataframe
#
# - modelEvaluation function takes the actual labels and predicted labels to calculate the the accuracy, precision, recall and f1-score

# %%
def count_digit(num):
    count = 0
    while num != 0:
        num //= 10
        count += 1
    return count

def check_shape(df):
    rows, cols = df.shape
    print("\nNumber or rows in dataset: {}".format(rows))
    print("==========================={}".format(count_digit(rows)*'='))
    print("\nNumber or columns in dataset: {}".format(cols))
    print("=============================={}".format(count_digit(cols)*'='))
    
def modelEvaluation(predictions, y_test_set, model_name, classes):
    # Print model evaluation to predicted result    
    print("==========",model_name,"==========")
    print ("\nAccuracy on validation set: {:.4f}".format(accuracy_score(y_test_set, predictions)))    
    print ("\nClassification report : \n", classification_report(y_test_set, predictions, target_names = classes))
#     print ("\nConfusion Matrix : \n", confusion_matrix(y_test_set,predictions))
    sns.heatmap(confusion_matrix(y_test_set, predictions),annot=True,yticklabels=classes, xticklabels=classes, fmt='g',cmap='jet')
    
    plt.title('Confusion Matrix of {}'.format(model_name))
    plt.xlabel('predicted Labels')
    plt.ylabel('Actual Labels')
#     plt.tight_layout()
    plt.show()
    results = [accuracy_score(y_test_set, predictions), precision_score(y_test_set, predictions,average='macro'),
              recall_score(y_test_set, predictions,average='macro'),f1_score(y_test_set, predictions,average='macro')]#store results of model
    return results

# %% [markdown]
# # Understand Sample Data
# ## Dataset Samples and Features Count
#
# - display the column names in the dataset
# - display the count of samples in the dataset

# %%
# Understand Sample Data

print("\n\nAttributes in Sample Data:")
print("==========================\n")

print(df.columns)

print("\n\nNumber of Instances in Sample Data:",len(df.index))
print("===================================={}\n".format(count_digit(len(df.index))*'='))
# Out:
# Attributes in Sample Data:
# ==========================
#
# Index(['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'C10', 'C11',
#        'C12', 'C13', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21',
#        'C22', 'C23', 'C24', 'C25', 'C26', 'C27', 'C28', 'C29', 'C30', 'C31',
#        'C32', 'C33', 'C34', 'C35', 'C36', 'C37', 'C38', 'C39', 'C40', 'C41',
#        'C42', 'C43', 'C44', 'C45', 'C46', 'C47', 'C48', 'C49', 'C50', 'C51',
#        'C52', 'C53', 'C54'],
#       dtype='object')
#
#
# Number of Instances in Sample Data: 270000
# ==========================================

# %% [markdown]
# ## Rename Columns
# - just rename the column

# %%
rename_column = True
# column_dict = {"Existing Name": "New Column"}
column_dict = {"C1": "time", "C2": "label"}

if rename_column:
    df = df.rename(columns=column_dict)
    
    print("\n\nAttributes in Sample Data:")
    print("==========================\n")
    print(df.columns)
    
    print("\n\nSample Data:")
    print("============\n")
    print(df.head(2))
# Out:
# Attributes in Sample Data:
# ==========================
#
# Index(['time', 'label', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'C10', 'C11',
#        'C12', 'C13', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21',
#        'C22', 'C23', 'C24', 'C25', 'C26', 'C27', 'C28', 'C29', 'C30', 'C31',
#        'C32', 'C33', 'C34', 'C35', 'C36', 'C37', 'C38', 'C39', 'C40', 'C41',
#        'C42', 'C43', 'C44', 'C45', 'C46', 'C47', 'C48', 'C49', 'C50', 'C51',
#        'C52', 'C53', 'C54'],
#       dtype='object')
#
#
# Sample Data:
# ============
#
#      time  label  C3       C4        C5       C6       C7        C8       C9  \
# 0  245.60      1 NaN  31.2500  8.454240 -1.87144  4.59909  8.451590 -1.82178
# 1  141.46      1 NaN  31.1875  0.618133  5.84674  7.95803  0.448719  5.79011
#
#        C10       C11       C12       C13       C14      C15      C16  \
# 0  4.83646 -0.003862  0.035060 -0.012050  -1.03899  16.9162 -40.3566
# 1  8.01423  0.030756 -0.002772 -0.011148 -32.48750  16.6565 -39.0734
#
#         C17       C18       C19       C20      C21       C22       C23  \
# 0  0.859231  0.163914  0.471863  0.110452  33.5000  1.148240 -0.256525
# 1  1.000000  0.000000  0.000000  0.000000  32.9375  0.962296  1.927710
#
#        C24      C25       C26      C27       C28       C29       C30      C31  \
# 0  9.43440  1.17093 -0.269187  9.82580  0.021833 -0.020483 -0.013267  30.9394
# 1  9.38521  0.92726  1.950510  9.48612 -0.039448 -0.037787 -0.015004  38.8676
#
#         C32      C33       C34       C35       C36       C37      C38  \
# 0   8.48299 -28.3655  0.992143  0.013796  0.060311  0.108739  31.5625
# 1  10.46660 -54.2290  1.000000  0.000000  0.000000  0.000000  31.5625
#
#         C39      C40       C41       C42      C43      C44       C45  \
# 0  0.731510 -9.73096  0.630554  0.679572 -9.69403  1.12584  0.013166
# 1 -0.623762 -7.61323 -6.612740 -0.583058 -7.41971 -6.44238  0.022383
#
#         C46       C47      C48      C49      C50       C51       C52  \
# 0 -0.001145  0.012269 -15.7793  19.1345 -8.38399  0.165813  0.107752
# 1 -0.006306  0.016184 -14.3246  45.0746 -4.90095  1.000000  0.000000
#
#         C53       C54
# 0  0.653892 -0.730289
# 1  0.000000  0.000000

# %% [markdown]
# ## Initial Class Distribution
# - check the class distribution in the dataframe.
# - plot the class distribution in bar chat form

# %%
# print(df.label.value_counts(), "\n")

df['label'].value_counts()
plt.style.use('ggplot')
df.value_counts('label').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='label'>

# %% [markdown]
# - check the class distribution in the dataframe.
# - plot the class distribution in pie chat form

# %%
classes_counts = df.value_counts('label')
values = np.array(classes_counts)
mylabels = list(classes_counts.index)

plt.pie(values, labels = mylabels)
plt.legend()
plt.title('Dataset Class Distribution')
# plt.ylabel('Counts')
plt.show()

# %% [markdown]
# # Preprocessing Data
# - reset index

# %%
df = df.reset_index()

# %% [markdown]
# ## Drop Unwanted Classes
# - drop the other activity (0) class samples.
# - As the other activity is not defined and usually ither class is the combination of different, thats why drop this class.
# - claculate and display the class ditribution afetr removing unneccesery classes.

# %%
df.drop(df[df['label'] == 0].index, inplace = True)
# print(df['label'].value_counts(), "\n")

df['label'].value_counts()
plt.style.use('ggplot')
df.value_counts('label').plot(kind='bar')
plt.xticks(rotation=45, horizontalalignment='right')
plt.title('Dataset Class Distribution')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# # Feature Extraction
# - remove the samples with Null and NAN values.

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %% [markdown]
# - seperate the input features and output label into distinct variables

# %%
features = list(df.columns[4:])
features.insert(0, "label")
df = df[features]
df = clean_dataset(df)
df.shape
# Out:
# (267329, 52)

# %%
features = list(df.columns[1:])
X = df[features]
y = df['label']

X.shape
# Out:
# (267329, 51)

# %%
df['label'].map(int).map(str).value_counts()
plt.style.use('ggplot')
df.value_counts('label').plot(kind='bar')
plt.xticks(rotation=45, horizontalalignment='right')
plt.title('Dataset Class Distribution')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# # Train Test Split
# - function for spliting the dataset into different sub groups

# %%
def split_df(X, y, split_index):
    if split_index==0:
        X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)
        return X_train,X_test,y_train,y_test
    if split_index==1:
        X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)
        X_train,X_val,y_train,y_val = train_test_split(X_train, y_train, test_size=0.1)
        return X_train, X_test, X_val, y_train, y_test, y_val

# %% [markdown]
# - split dataframe into train test sets

# %%
split_index = 0
split = ['train_test', 'train_test_val']

# y = df['encoded_label']
X_train,X_test,y_train,y_test = split_df(X, y, split_index)

# %% [markdown]
# - check the shape of the splited sets

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (213863, 51)
# (53466, 51)

# %% [markdown]
# - display the class distribution in train and test set

# %%
X_train1,X_test1,y_train1,y_test1 = split_df(X, y, split_index)

print(y_train1.value_counts(), "\n")
plt.style.use('ggplot')
y_train1.value_counts().plot(kind='bar')
plt.xticks(rotation=45, horizontalalignment='right')
plt.title('Training Set Class Distribution')
plt.ylabel('Counts')
plt.show()

print(y_test1.value_counts(), "\n")
plt.style.use('ggplot')
y_test1.value_counts().plot(kind='bar')
plt.xticks(rotation=45, horizontalalignment='right')
plt.title('Testing Set Class Distribution')
plt.ylabel('Counts')
plt.show()

# print(y_val1.value_counts(), "\n")
# plt.style.use('ggplot')
# y_val1.value_counts().plot(kind='bar')
# plt.xticks(rotation=45, horizontalalignment='right')
# plt.title('Validation Set Class Distribution')
# plt.ylabel('Counts')

# del X_train1,X_test1,X_val1,y_train1,y_test1,y_val1
# Out:
# 9.0     12070
# 2.0     12068
# 1.0     12052
# 18.0    11971
# 10.0    11968
# 6.0     11968
# 3.0     11955
# 12.0    11945
# 11.0    11923
# 16.0    11920
# 13.0    11905
# 19.0    11901
# 17.0    11875
# 20.0    11789
# 7.0     11764
# 5.0     11691
# 24.0    11591
# 4.0     11507
# Name: label, dtype: int64
# 13.0    3086
# 17.0    3081
# 11.0    3056
# 16.0    3052
# 19.0    3040
# 12.0    3033
# 10.0    3007
# 3.0     2973
# 18.0    2969
# 7.0     2942
# 1.0     2934
# 9.0     2925
# 6.0     2918
# 4.0     2910
# 5.0     2906
# 2.0     2895
# 24.0    2875
# 20.0    2864
# Name: label, dtype: int64

# %% [markdown]
# # Machine Learning
# - extract classes name into classes variable
# - create a distionary to append the results of trained models

# %%
classes = list(df['label'].map(int).map(str).unique())
collect_results_of_all_model= {
    'Metrics':['accuracy','precision','recall','f1-score']
} #dic form store results of all models

# %% [markdown]
# ## Logistic Regression
# - import model
# - load model
# - train model with training data
# - make predictionwith trained model on test data

# %%
from sklearn.linear_model import LogisticRegression

lr_classifier = LogisticRegression(random_state=0)
lr_classifier.fit(X_train, y_train)

preds = lr_classifier.predict(X_test)

# %% [markdown]
# - calculate evaluation measures (accuracy, precision, recall, f1-score) using test labels and predicted labels
# - append results into dictionary with the key of model name

# %%
LR_res=modelEvaluation(preds, y_test, 'LR', classes)
collect_results_of_all_model["LR"] = LR_res
# Out:
# ========== LR ==========
#
# Accuracy on validation set: 0.6303
#
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.92      0.92      0.92      2915
#            2       0.71      0.78      0.74      3025
#            3       0.58      0.71      0.64      2993
#            4       0.48      0.43      0.45      2926
#            5       0.54      0.39      0.45      2873
#            6       0.79      0.84      0.81      2964
#            7       0.57      0.43      0.49      2839
#            9       0.93      0.97      0.95      3030
#           10       0.74      0.86      0.79      2968
#           11       0.98      0.98      0.98      3052
#           12       0.42      0.44      0.43      2983
#           13       0.39      0.34      0.36      3067
#           16       0.61      0.62      0.62      2931
#           17       0.54      0.68      0.60      2970
#           18       0.50      0.47      0.48      3041
#           19       0.50      0.37      0.43      3002
#           20       0.57      0.61      0.59      2941
#           24       0.45      0.47      0.46      2946
#
#     accuracy                           0.63     53466
#    macro avg       0.62      0.63      0.62     53466
# weighted avg       0.62      0.63      0.62     53466

# %% [markdown]
# ## Decision Tree Model
# - import model
# - load model
# - train model with training data
# - make predictionwith trained model on test data

# %%
from sklearn.tree import DecisionTreeClassifier

DT_classifier = DecisionTreeClassifier(random_state=0)
DT_classifier.fit(X_train,y_train)

preds = DT_classifier.predict(X_test)

# %% [markdown]
# ## Desicion Tree Result

# %% [markdown]
# - calculate evaluation measures (accuracy, precision, recall, f1-score) using test labels and predicted labels
# - append results into dictionary with the key of model name

# %%
DT_res=modelEvaluation(preds, y_test, 'DT', classes)
collect_results_of_all_model["DT"] = DT_res
# Out:
# ========== DT ==========
#
# Accuracy on validation set: 0.9805
#
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99      2915
#            2       0.99      0.99      0.99      3025
#            3       0.98      0.99      0.99      2993
#            4       0.97      0.97      0.97      2926
#            5       0.98      0.99      0.98      2873
#            6       0.98      0.98      0.98      2964
#            7       0.98      0.98      0.98      2839
#            9       1.00      1.00      1.00      3030
#           10       1.00      1.00      1.00      2968
#           11       1.00      1.00      1.00      3052
#           12       0.93      0.92      0.93      2983
#           13       0.95      0.94      0.95      3067
#           16       0.95      0.96      0.95      2931
#           17       0.98      0.98      0.98      2970
#           18       0.99      0.99      0.99      3041
#           19       0.98      0.98      0.98      3002
#           20       1.00      1.00      1.00      2941
#           24       1.00      1.00      1.00      2946
#
#     accuracy                           0.98     53466
#    macro avg       0.98      0.98      0.98     53466
# weighted avg       0.98      0.98      0.98     53466

# %% [markdown]
# ## Random Forest
# - import model
# - load model
# - train model with training data
# - make predictionwith trained model on test data

# %%
from sklearn.ensemble import RandomForestClassifier

RF = RandomForestClassifier(max_depth=5, bootstrap=100)
RF.fit(X_train,y_train)

preds_RF = RF.predict(X_test)

# %% [markdown]
# ## Random Forest Results
# - calculate evaluation measures (accuracy, precision, recall, f1-score) using test labels and predicted labels
# - append results into dictionary with the key of model name

# %%
RF_res = modelEvaluation(preds_RF, y_test, 'Random Forest', classes)
collect_results_of_all_model["RF_CLassifier"] = RF_res
# Out:
# ========== Random Forest ==========
#
# Accuracy on validation set: 0.7043
#
# Classification report :
#                precision    recall  f1-score   support
#
#            1       1.00      0.92      0.96      2915
#            2       0.66      0.93      0.77      3025
#            3       0.53      0.82      0.64      2993
#            4       0.54      0.55      0.54      2926
#            5       0.96      0.51      0.66      2873
#            6       0.79      0.89      0.84      2964
#            7       0.72      0.44      0.55      2839
#            9       1.00      0.98      0.99      3030
#           10       0.81      0.98      0.89      2968
#           11       0.99      0.99      0.99      3052
#           12       0.45      0.45      0.45      2983
#           13       0.59      0.21      0.31      3067
#           16       0.62      0.65      0.63      2931
#           17       0.47      0.84      0.60      2970
#           18       0.62      0.48      0.54      3041
#           19       0.86      0.29      0.44      3002
#           20       0.66      1.00      0.79      2941
#           24       0.93      0.75      0.83      2946
#
#     accuracy                           0.70     53466
#    macro avg       0.73      0.70      0.69     53466
# weighted avg       0.73      0.70      0.69     53466

# %% [markdown]
# ## Naive Bayes
# - import model
# - load model
# - train model with training data
# - make predictionwith trained model on test data

# %%
from sklearn.naive_bayes import GaussianNB

NB_classifier = GaussianNB()
NB_classifier.fit(X_train,y_train)

preds = NB_classifier.predict(X_test)

# %% [markdown]
# ## Naive Bayes Reuslts
# - calculate evaluation measures (accuracy, precision, recall, f1-score) using test labels and predicted labels
# - append results into dictionary with the key of model name

# %%
NB_res=modelEvaluation(preds, y_test, 'NB', classes)
collect_results_of_all_model["NB"] = NB_res
# Out:
# ========== NB ==========
#
# Accuracy on validation set: 0.7290
#
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.96      0.89      0.93      2915
#            2       0.86      0.78      0.82      3025
#            3       0.53      0.83      0.65      2993
#            4       0.71      0.75      0.73      2926
#            5       0.72      0.66      0.69      2873
#            6       0.92      0.92      0.92      2964
#            7       0.64      0.67      0.66      2839
#            9       1.00      0.97      0.98      3030
#           10       0.94      0.95      0.94      2968
#           11       0.95      0.99      0.97      3052
#           12       0.59      0.50      0.54      2983
#           13       0.63      0.45      0.52      3067
#           16       0.64      0.75      0.69      2931
#           17       0.50      0.80      0.62      2970
#           18       0.57      0.43      0.49      3041
#           19       0.47      0.40      0.43      3002
#           20       0.78      0.71      0.75      2941
#           24       0.90      0.70      0.79      2946
#
#     accuracy                           0.73     53466
#    macro avg       0.74      0.73      0.73     53466
# weighted avg       0.74      0.73      0.73     53466

# %% [markdown]
# ## AdaBoost
# - import model
# - load model
# - train model with training data
# - make predictionwith trained model on test data

# %%
from sklearn.ensemble import AdaBoostClassifier

AB_classifier = AdaBoostClassifier(n_estimators=10, random_state=0)
AB_classifier.fit(X_train,y_train)

preds = AB_classifier.predict(X_test)

# %% [markdown]
# ## AdaBoost Result
# - calculate evaluation measures (accuracy, precision, recall, f1-score) using test labels and predicted labels
# - append results into dictionary with the key of model name

# %%
Ada_res=modelEvaluation(preds, y_test, 'AdaBoot', classes)
collect_results_of_all_model["Ada"] = Ada_res
# Out:
# ========== AdaBoot ==========
#
# Accuracy on validation set: 0.2531
#
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.97      0.89      0.93      2915
#            2       0.00      0.00      0.00      3025
#            3       0.00      0.00      0.00      2993
#            4       0.00      0.00      0.00      2926
#            5       0.56      0.15      0.24      2873
#            6       0.78      0.10      0.17      2964
#            7       0.89      0.30      0.45      2839
#            9       0.00      0.00      0.00      3030
#           10       0.00      0.00      0.00      2968
#           11       0.77      0.95      0.85      3052
#           12       0.10      0.90      0.17      2983
#           13       0.24      0.03      0.06      3067
#           16       0.00      0.00      0.00      2931
#           17       0.00      0.00      0.00      2970
#           18       0.00      0.00      0.00      3041
#           19       0.11      0.20      0.14      3002
#           20       0.27      0.91      0.41      2941
#           24       0.41      0.14      0.20      2946
#
#     accuracy                           0.25     53466
#    macro avg       0.28      0.25      0.20     53466
# weighted avg       0.28      0.25      0.20     53466

# %% [markdown]
# ## SVM Model

# %%
# from sklearn.svm import SVC

# SVC_classifier = SVC(max_iter=200)
# SVC_classifier.fit(X_train,y_train)

# preds = SVC_classifier.predict(X_test)

# %% [markdown]
# ## SVM Results

# %%
# SVC_res=modelEvaluation(preds, y_test, 'SVM', classes)
# collect_results_of_all_model["SVC"] = SVC_res

# %% [markdown]
# ## KNN Model
# - import model
# - load model
# - train model with training data
# - make predictionwith trained model on test data

# %%
from sklearn.neighbors import KNeighborsClassifier

neighbors_clf = KNeighborsClassifier(n_neighbors=5,)
neighbors_clf.fit(X_train,y_train)

KNN_preds = neighbors_clf.predict(X_test)

# %% [markdown]
# ## KNN Results
# - calculate evaluation measures (accuracy, precision, recall, f1-score) using test labels and predicted labels
# - append results into dictionary with the key of model name

# %%
KNN_res = modelEvaluation(KNN_preds,y_test,'KNN',classes)
collect_results_of_all_model["KNN"] = KNN_res
# Out:
# ========== KNN ==========
#
# Accuracy on validation set: 0.9626
#
# Classification report :
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      2915
#            2       0.99      0.99      0.99      3025
#            3       0.98      0.99      0.99      2993
#            4       0.87      0.91      0.89      2926
#            5       0.95      0.98      0.96      2873
#            6       0.97      1.00      0.98      2964
#            7       0.90      0.95      0.92      2839
#            9       1.00      1.00      1.00      3030
#           10       1.00      1.00      1.00      2968
#           11       1.00      1.00      1.00      3052
#           12       0.92      0.90      0.91      2983
#           13       0.96      0.88      0.92      3067
#           16       0.96      0.96      0.96      2931
#           17       0.96      0.95      0.96      2970
#           18       0.95      0.99      0.97      3041
#           19       0.97      0.95      0.96      3002
#           20       0.96      0.89      0.93      2941
#           24       0.98      1.00      0.99      2946
#
#     accuracy                           0.96     53466
#    macro avg       0.96      0.96      0.96     53466
# weighted avg       0.96      0.96      0.96     53466

# %% [markdown]
# # Rsults Comparison
# ## Comparison Table
# - create dataframe using distionary of model results
# - set the index of dataframe
# - display the dataframe

# %%
from tabulate import tabulate 
metrics_data_frame = pd.DataFrame(collect_results_of_all_model) # create dataframe
metrics_data_frame = metrics_data_frame.set_index('Metrics') # set index
# displaying the DataFrame
print(tabulate(metrics_data_frame, headers = 'keys', tablefmt = 'psql')) # convert results in to table
# Out:
# +-----------+----------+----------+-----------------+----------+----------+----------+
# | Metrics   |       LR |       DT |   RF_CLassifier |       NB |      Ada |      KNN |
# |-----------+----------+----------+-----------------+----------+----------+----------|
# | accuracy  | 0.630251 | 0.98053  |        0.704279 | 0.728987 | 0.253114 | 0.962593 |
# | precision | 0.623196 | 0.980504 |        0.732931 | 0.740176 | 0.283529 | 0.962656 |
# | recall    | 0.629233 | 0.980551 |        0.704016 | 0.729323 | 0.253795 | 0.962537 |
# | f1-score  | 0.622977 | 0.980521 |        0.690152 | 0.727853 | 0.201719 | 0.962309 |
# +-----------+----------+----------+-----------------+----------+----------+----------+

# %% [markdown]
# - display each row of the above dataframe into a single group
# - in the below bar chat each group showed the accuracy, precision, recall, f1-score respectivelly for each model.

# %%
metrics_data_frame.plot(kind='bar', figsize=(20,10)) # sho comparison base of mertics
plt.xticks(rotation=45, horizontalalignment='right')
plt.title('Comparison Graph')
plt.ylabel('Score')
plt.xlabel("Evaluation Measure")
# Out:
# Text(0.5, 0, 'Evaluation Measure')
