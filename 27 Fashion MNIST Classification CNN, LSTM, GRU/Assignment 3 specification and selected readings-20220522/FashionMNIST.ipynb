# %% [markdown]
# # FASHION MNIST CLASSIFICATION

# %%
# import libraries
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# 2022-06-01 15:59:05.171338: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1

# %% [markdown]
# **Loading the train and test files**

# %%
# import files
data_train_file = "fashion-mnist_train.csv"
data_test_file = "fashion-mnist_test.csv"

# read files csv
df_train = pd.read_csv(data_train_file)
df_test = pd.read_csv(data_test_file)

# data as array in order to reshape them
train_data = np.array(df_train, dtype='float32')
test_data = np.array(df_test, dtype='float32')

# %%
print("Train data shape:", train_data.shape)
print("Test data shape:", test_data.shape)
# Out:
# Train data shape: (60000, 785)
# Test data shape: (10000, 785)

# %%
X_train=train_data[:,1:]/255.0
Y_train=train_data[:,0]
X_test = test_data[:,1:]/255.0
Y_test = test_data[:,0]

# %%
print("X_train shape", X_train.shape)
print("Y_train shape", Y_train.shape)
print("X_test shape", X_test.shape)
print("Y_test shape", Y_test.shape)
# Out:
# X_train shape (60000, 784)
# Y_train shape (60000,)
# X_test shape (10000, 784)
# Y_test shape (10000,)

# %%
pd.Series(Y_train).value_counts().plot(kind='bar')
plt.savefig("traindata.jpg")
plt.show()
pd.Series(Y_test).value_counts().plot(kind='bar')
plt.show()

# %%
X_train_reshaped = X_train.reshape(X_train.shape[0],*(28,28))
X_test_reshaped = X_test.reshape(X_test.shape[0],*(28,28))

# %%
plt.figure(figsize = (10,10))

for i in range(30):
    plt.subplot(6,6,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train_reshaped[i], cmap='gray')
    plt.xlabel(Y_train[i])
    
plt.show()

# %%
X_train_reshaped = X_train.reshape(X_train.shape[0],*(28,28,1))
X_test_reshaped = X_test.reshape(X_test.shape[0],*(28,28,1))
print('x_test shape: {}'.format(X_train_reshaped.shape))
# Out:
# x_test shape: (60000, 28, 28, 1)

# %%
from tensorflow.keras.utils import to_categorical

optimizers = []
loss_functions = []
loss_scores = []
acc_scores = []
converg_rates = []

for opt in ["adagrad", "sgd", "adam","adadelta"]:
    for loss_fun in ['sparse_categorical_crossentropy', 'categorical_crossentropy', 'huber_loss']:

        print("Optimizer: ", opt, "  Loss Function: ", loss_fun)

        model = models.Sequential()

        model.add(layers.Conv2D(32,(3,3), activation = 'relu', input_shape = (28,28,1)))
        model.add(layers.MaxPool2D((2,2), strides=1))
        model.add(layers.BatchNormalization())
        model.add(layers.Dropout(0.1))

        model.add(layers.Conv2D(64,(3,3), activation = 'relu'))
        model.add(layers.MaxPool2D((2,2), strides=1))
        model.add(layers.BatchNormalization())
        model.add(layers.Dropout(0.1))


        model.add(layers.Flatten())
        model.add(layers.Dense(10))
#         model.summary()

        model.compile(optimizer = opt, loss = loss_fun, metrics = ['accuracy'])

        if loss_fun == 'sparse_categorical_crossentropy':
            history = model.fit(X_train_reshaped, Y_train, epochs=10, validation_data=(X_test_reshaped, Y_test))
        else:
            history = model.fit(X_train_reshaped, to_categorical(Y_train), epochs=10, validation_data=(X_test_reshaped, to_categorical(Y_test)))
        
      
        # Displaying the model results
        plt.plot(history.history['accuracy'], label = 'accuracy')
        plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
        plt.plot(history.history['loss'], label = 'loss')
        plt.plot(history.history['val_loss'], label = 'val_loss')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.legend(loc='upper right')
        plt.show()

        # Evaluating the model
        if loss_fun == 'sparse_categorical_crossentropy':
            test_loss, test_acc = model.evaluate(X_test_reshaped, Y_test, verbose = 2) 
        else:
            test_loss, test_acc = model.evaluate(X_test_reshaped, to_categorical(Y_test), verbose = 2) 

        # Displaying the results
        print("Loss: ",test_loss)
        print("Accuracy: ",test_acc)
        
        # calculate convergence 
        initial_loss = history.history['loss'][0]
        final_loss = history.history['loss'][-1]
        convergence_length = len(history.history['loss']) - 1
        convergence_rate = abs(initial_loss - final_loss) / convergence_length
        print(convergence_rate)
        # Saving the scores
        optimizers.append(opt)
        loss_functions.append(loss_fun)
        loss_scores.append(test_loss)
        acc_scores.append(test_acc)
        converg_rates.append(convergence_rate)
        # Deleting the model obj
        del model
# Out:
# Optimizer:  adagrad   Loss Function:  sparse_categorical_crossentropy
# Epoch 1/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.8659 - accuracy: 0.4568 - val_loss: 1.6919 - val_accuracy: 0.4734
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.7379 - accuracy: 0.5153 - val_loss: 2.0117 - val_accuracy: 0.5203
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.8519 - accuracy: 0.5735 - val_loss: 1.8159 - val_accuracy: 0.5055
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 2.0010 - accuracy: 0.5076 - val_loss: 2.0075 - val_accuracy: 0.4814
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.9063 - accuracy: 0.5382 - val_loss: 1.8760 - val_accuracy: 0.5075
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.9495 - accuracy: 0.5495 - val_loss: 2.2943 - val_accuracy: 0.5149
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 2.3925 - accuracy: 0.5005 - val_loss: 2.5359 - val_accuracy: 0.5082
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.1805 - accuracy: 0.5444 - val_loss: 2.2008 - val_accuracy: 0.5908
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 2.0520 - accuracy: 0.5896 - val_loss: 2.0975 - val_accuracy: 0.5993
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.0175 - accuracy: 0.5860 - val_loss: 2.0613 - val_accuracy: 0.5892
# 313/313 - 1s - loss: 2.0613 - accuracy: 0.5892
# Loss:  2.061306953430176
# Accuracy:  0.5892000198364258
# 0.016842020882500544
# Optimizer:  adagrad   Loss Function:  categorical_crossentropy
# Epoch 1/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 8.4218 - accuracy: 0.1615 - val_loss: 8.4419 - val_accuracy: 0.1297
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 8.6787 - accuracy: 0.0940 - val_loss: 7.1610 - val_accuracy: 0.1004
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 8.3940 - accuracy: 0.1096 - val_loss: 7.1547 - val_accuracy: 0.1677
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 7.9293 - accuracy: 0.1318 - val_loss: 8.3505 - val_accuracy: 0.1811
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 8.1532 - accuracy: 0.1306 - val_loss: 8.1767 - val_accuracy: 0.1595
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 8.6808 - accuracy: 0.1275 - val_loss: 8.2340 - val_accuracy: 0.1340
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 8.6448 - accuracy: 0.1142 - val_loss: 7.7608 - val_accuracy: 0.1300
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 7.7129 - accuracy: 0.1083 - val_loss: 7.0092 - val_accuracy: 0.1131
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 8.3819 - accuracy: 0.0955 - val_loss: 7.5867 - val_accuracy: 0.1193
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 8.4453 - accuracy: 0.1099 - val_loss: 8.7697 - val_accuracy: 0.1305
# 313/313 - 1s - loss: 8.7697 - accuracy: 0.1305
# Loss:  8.769673347473145
# Accuracy:  0.13050000369548798
# 0.0026119020250108507
# Optimizer:  adagrad   Loss Function:  huber_loss
# Epoch 1/10
#    1/1875 [..............................] - ETA: 2s - loss: 0.7167 - accuracy: 0.1250WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0011s vs `on_train_batch_end` time: 0.0031s). Check your callbacks.
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2097 - accuracy: 0.3722 - val_loss: 0.0508 - val_accuracy: 0.6978
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1438 - accuracy: 0.4609 - val_loss: 0.0338 - val_accuracy: 0.7938
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1240 - accuracy: 0.4972 - val_loss: 0.0283 - val_accuracy: 0.8108
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1114 - accuracy: 0.5229 - val_loss: 0.0268 - val_accuracy: 0.8327
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1028 - accuracy: 0.5477 - val_loss: 0.0225 - val_accuracy: 0.8397
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0959 - accuracy: 0.5675 - val_loss: 0.0220 - val_accuracy: 0.8424
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0905 - accuracy: 0.5828 - val_loss: 0.0220 - val_accuracy: 0.8369
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0860 - accuracy: 0.5963 - val_loss: 0.0212 - val_accuracy: 0.8389
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0820 - accuracy: 0.6098 - val_loss: 0.0192 - val_accuracy: 0.8508
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0784 - accuracy: 0.6230 - val_loss: 0.0184 - val_accuracy: 0.8588
# 313/313 - 1s - loss: 0.0184 - accuracy: 0.8588
# Loss:  0.018367290496826172
# Accuracy:  0.8587999939918518
# 0.01459220548470815
# Optimizer:  sgd   Loss Function:  sparse_categorical_crossentropy
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 4.4715 - accuracy: 0.2470 - val_loss: 3.6303 - val_accuracy: 0.2418
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 3.4621 - accuracy: 0.2869 - val_loss: 3.5478 - val_accuracy: 0.2239
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 3.3610 - accuracy: 0.3064 - val_loss: 3.3737 - val_accuracy: 0.3879
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 3.7393 - accuracy: 0.3095 - val_loss: 3.3121 - val_accuracy: 0.3429
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.4983 - accuracy: 0.3652 - val_loss: 1.7706 - val_accuracy: 0.3983
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.8057 - accuracy: 0.3578 - val_loss: 1.6768 - val_accuracy: 0.3818
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.7355 - accuracy: 0.3355 - val_loss: 1.7699 - val_accuracy: 0.3403
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.7572 - accuracy: 0.3863 - val_loss: 1.7361 - val_accuracy: 0.4189
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.6635 - accuracy: 0.4236 - val_loss: 1.6352 - val_accuracy: 0.4199
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.6793 - accuracy: 0.4414 - val_loss: 1.7396 - val_accuracy: 0.4495
# 313/313 - 0s - loss: 1.7396 - accuracy: 0.4495
# Loss:  1.7396056652069092
# Accuracy:  0.4494999945163727
# 0.3102445602416992
# Optimizer:  sgd   Loss Function:  categorical_crossentropy
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 8.3945 - accuracy: 0.1857 - val_loss: 8.2599 - val_accuracy: 0.0963
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 6.6230 - accuracy: 0.1042 - val_loss: 6.4946 - val_accuracy: 0.1524
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 7.1093 - accuracy: 0.1653 - val_loss: 9.1544 - val_accuracy: 0.1000
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 7.3953 - accuracy: 0.0538 - val_loss: 7.3639 - val_accuracy: 0.1227
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 7.1656 - accuracy: 0.0877 - val_loss: 6.9825 - val_accuracy: 0.0830
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 7.4525 - accuracy: 0.1266 - val_loss: 7.6699 - val_accuracy: 0.0942
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 8.2061 - accuracy: 0.1740 - val_loss: 7.3677 - val_accuracy: 0.1824
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 8.9780 - accuracy: 0.1610 - val_loss: 8.5954 - val_accuracy: 0.1187
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 8.1762 - accuracy: 0.1557 - val_loss: 7.1099 - val_accuracy: 0.1340
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 7.1962 - accuracy: 0.1873 - val_loss: 7.3450 - val_accuracy: 0.1995
# 313/313 - 1s - loss: 7.3450 - accuracy: 0.1995
# Loss:  7.344986915588379
# Accuracy:  0.19949999451637268
# 0.1331470807393392
# Optimizer:  sgd   Loss Function:  huber_loss
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3509 - accuracy: 0.3274 - val_loss: 0.1150 - val_accuracy: 0.5380
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1348 - accuracy: 0.5218 - val_loss: 0.0580 - val_accuracy: 0.7343
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0753 - accuracy: 0.6637 - val_loss: 0.0312 - val_accuracy: 0.8270
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0505 - accuracy: 0.7534 - val_loss: 0.0258 - val_accuracy: 0.8380
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0382 - accuracy: 0.8029 - val_loss: 0.0221 - val_accuracy: 0.8566
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0310 - accuracy: 0.8334 - val_loss: 0.0171 - val_accuracy: 0.8693
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0266 - accuracy: 0.8500 - val_loss: 0.0172 - val_accuracy: 0.8810
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0235 - accuracy: 0.8628 - val_loss: 0.0172 - val_accuracy: 0.8600
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0213 - accuracy: 0.8706 - val_loss: 0.0147 - val_accuracy: 0.8879
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0195 - accuracy: 0.8786 - val_loss: 0.0146 - val_accuracy: 0.8885
# 313/313 - 1s - loss: 0.0146 - accuracy: 0.8885
# Loss:  0.014604919590055943
# Accuracy:  0.8884999752044678
# 0.03681548891796006
# Optimizer:  adam   Loss Function:  sparse_categorical_crossentropy
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.9585 - accuracy: 0.3497 - val_loss: 4.6311 - val_accuracy: 0.2908
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.3684 - accuracy: 0.2274 - val_loss: 2.2758 - val_accuracy: 0.2382
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.4128 - accuracy: 0.2659 - val_loss: 3.0031 - val_accuracy: 0.2277
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.2178 - accuracy: 0.2753 - val_loss: 2.1587 - val_accuracy: 0.2769
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.2299 - accuracy: 0.2114 - val_loss: 2.3090 - val_accuracy: 0.1169
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.3114 - accuracy: 0.1112 - val_loss: 2.3134 - val_accuracy: 0.1058
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.3150 - accuracy: 0.1214 - val_loss: 2.3030 - val_accuracy: 0.1244
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 2.3206 - accuracy: 0.1731 - val_loss: 2.3305 - val_accuracy: 0.2773
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 2.3701 - accuracy: 0.2104 - val_loss: 2.2967 - val_accuracy: 0.1381
# Epoch 10/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 2.3021 - accuracy: 0.1199 - val_loss: 2.3009 - val_accuracy: 0.1223
# 313/313 - 1s - loss: 2.3009 - accuracy: 0.1223
# Loss:  2.300887107849121
# Accuracy:  0.12229999899864197
# 0.07293176651000977
# Optimizer:  adam   Loss Function:  categorical_crossentropy
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 8.3949 - accuracy: 0.2539 - val_loss: 8.0083 - val_accuracy: 0.2768
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 8.3380 - accuracy: 0.2195 - val_loss: 8.0581 - val_accuracy: 0.1018
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 8.6177 - accuracy: 0.1420 - val_loss: 6.2151 - val_accuracy: 0.1407
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 9.0254 - accuracy: 0.1543 - val_loss: 6.4487 - val_accuracy: 0.1806
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 8.8189 - accuracy: 0.1814 - val_loss: 7.8820 - val_accuracy: 0.1860
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 8.5492 - accuracy: 0.1940 - val_loss: 10.0737 - val_accuracy: 0.1859
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 8.7766 - accuracy: 0.1695 - val_loss: 9.2634 - val_accuracy: 0.2015
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 7.5185 - accuracy: 0.1477 - val_loss: 6.9496 - val_accuracy: 0.1685
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 7.9689 - accuracy: 0.1786 - val_loss: 6.8804 - val_accuracy: 0.2325
# Epoch 10/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 7.1519 - accuracy: 0.2454 - val_loss: 6.4585 - val_accuracy: 0.2614
# 313/313 - 1s - loss: 6.4585 - accuracy: 0.2614
# Loss:  6.458471298217773
# Accuracy:  0.2614000141620636
# 0.13810994890001085
# Optimizer:  adam   Loss Function:  huber_loss
# Epoch 1/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3061 - accuracy: 0.5119 - val_loss: 0.0179 - val_accuracy: 0.8417
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0159 - accuracy: 0.8674 - val_loss: 0.0126 - val_accuracy: 0.8746
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0119 - accuracy: 0.8884 - val_loss: 0.0109 - val_accuracy: 0.8961
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0110 - accuracy: 0.8976 - val_loss: 0.0116 - val_accuracy: 0.8894
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0104 - accuracy: 0.9039 - val_loss: 0.0111 - val_accuracy: 0.8910
# Epoch 6/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0101 - accuracy: 0.9093 - val_loss: 0.0108 - val_accuracy: 0.9042
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0098 - accuracy: 0.9130 - val_loss: 0.0097 - val_accuracy: 0.9113
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0096 - accuracy: 0.9180 - val_loss: 0.0095 - val_accuracy: 0.9119
# Epoch 9/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0094 - accuracy: 0.9215 - val_loss: 0.0099 - val_accuracy: 0.9097
# Epoch 10/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0091 - accuracy: 0.9261 - val_loss: 0.0095 - val_accuracy: 0.9166
# 313/313 - 1s - loss: 0.0095 - accuracy: 0.9166
# Loss:  0.009546183049678802
# Accuracy:  0.9165999889373779
# 0.03299478296604422
# Optimizer:  adadelta   Loss Function:  sparse_categorical_crossentropy
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 6.0536 - accuracy: 0.2252 - val_loss: 3.9351 - val_accuracy: 0.3411
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 3.7608 - accuracy: 0.3810 - val_loss: 2.8420 - val_accuracy: 0.4340
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 2.8142 - accuracy: 0.4498 - val_loss: 2.3134 - val_accuracy: 0.4880
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 2.4317 - accuracy: 0.4988 - val_loss: 2.0824 - val_accuracy: 0.5352
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 2.2961 - accuracy: 0.5407 - val_loss: 2.0440 - val_accuracy: 0.5776
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 2.2572 - accuracy: 0.5779 - val_loss: 2.0883 - val_accuracy: 0.5903
# Epoch 7/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 2.2245 - accuracy: 0.5792 - val_loss: 2.0506 - val_accuracy: 0.5982
# Epoch 8/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 2.1896 - accuracy: 0.5770 - val_loss: 2.1614 - val_accuracy: 0.5855
# Epoch 9/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 2.2861 - accuracy: 0.5745 - val_loss: 2.3549 - val_accuracy: 0.5756
# Epoch 10/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 2.3447 - accuracy: 0.5666 - val_loss: 2.3561 - val_accuracy: 0.5598
# 313/313 - 1s - loss: 2.3561 - accuracy: 0.5598
# Loss:  2.356095314025879
# Accuracy:  0.5598000288009644
# 0.4121044741736518
# Optimizer:  adadelta   Loss Function:  categorical_crossentropy
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 7.6157 - accuracy: 0.1267 - val_loss: 7.7439 - val_accuracy: 0.1613
# Epoch 2/10
# 1875/1875 [==============================] - 10s 6ms/step - loss: 7.2962 - accuracy: 0.1524 - val_loss: 7.4406 - val_accuracy: 0.1914
# Epoch 3/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 7.3718 - accuracy: 0.1739 - val_loss: 7.1818 - val_accuracy: 0.2014
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 7.5103 - accuracy: 0.1890 - val_loss: 7.4874 - val_accuracy: 0.2142
# Epoch 5/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 7.7320 - accuracy: 0.1965 - val_loss: 7.5060 - val_accuracy: 0.2209
# Epoch 6/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 7.7161 - accuracy: 0.2031 - val_loss: 7.7938 - val_accuracy: 0.2293
# Epoch 7/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 7.7951 - accuracy: 0.2089 - val_loss: 7.7070 - val_accuracy: 0.2321
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 7.8421 - accuracy: 0.2146 - val_loss: 7.6291 - val_accuracy: 0.2324
# Epoch 9/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 7.7522 - accuracy: 0.2153 - val_loss: 7.5745 - val_accuracy: 0.2273
# Epoch 10/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 7.8612 - accuracy: 0.2134 - val_loss: 7.5610 - val_accuracy: 0.2240
# 313/313 - 0s - loss: 7.5610 - accuracy: 0.2240
# Loss:  7.561030387878418
# Accuracy:  0.2240000069141388
# 0.027271747589111328
# Optimizer:  adadelta   Loss Function:  huber_loss
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3793 - accuracy: 0.2178 - val_loss: 0.1704 - val_accuracy: 0.3340
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2837 - accuracy: 0.2794 - val_loss: 0.1305 - val_accuracy: 0.4110
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2505 - accuracy: 0.3090 - val_loss: 0.1070 - val_accuracy: 0.4614
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2288 - accuracy: 0.3291 - val_loss: 0.0894 - val_accuracy: 0.5292
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2122 - accuracy: 0.3443 - val_loss: 0.0788 - val_accuracy: 0.5539
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1998 - accuracy: 0.3588 - val_loss: 0.0683 - val_accuracy: 0.5909
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1903 - accuracy: 0.3713 - val_loss: 0.0621 - val_accuracy: 0.6168
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1816 - accuracy: 0.3831 - val_loss: 0.0584 - val_accuracy: 0.6301
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1751 - accuracy: 0.3914 - val_loss: 0.0532 - val_accuracy: 0.6622
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1688 - accuracy: 0.3995 - val_loss: 0.0489 - val_accuracy: 0.6833
# 313/313 - 1s - loss: 0.0489 - accuracy: 0.6833
# Loss:  0.0489342175424099
# Accuracy:  0.6833000183105469
# 0.023387937082184687

# %%
results = pd.DataFrame()
results["optimizer"] = optimizers
results["Loss Functions"] = loss_functions
results["Accuracy"] = acc_scores
results["Loss"] = loss_scores
results["rate"] = converg_rates
results
# Out:
#    optimizer                   Loss Functions  Accuracy      Loss      rate
# 0    adagrad  sparse_categorical_crossentropy    0.5892  2.061307  0.016842
# 1    adagrad         categorical_crossentropy    0.1305  8.769673  0.002612
# 2    adagrad                       huber_loss    0.8588  0.018367  0.014592
# 3        sgd  sparse_categorical_crossentropy    0.4495  1.739606  0.310245
# 4        sgd         categorical_crossentropy    0.1995  7.344987  0.133147
# 5        sgd                       huber_loss    0.8885  0.014605  0.036815
# 6       adam  sparse_categorical_crossentropy    0.1223  2.300887  0.072932
# 7       adam         categorical_crossentropy    0.2614  6.458471  0.138110
# 8       adam                       huber_loss    0.9166  0.009546  0.032995
# 9   adadelta  sparse_categorical_crossentropy    0.5598  2.356095  0.412104
# 10  adadelta         categorical_crossentropy    0.2240  7.561030  0.027272
# 11  adadelta                       huber_loss    0.6833  0.048934  0.023388
