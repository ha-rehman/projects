# %%
import re
import scipy
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf 
import matplotlib.pyplot as plt


from sklearn.svm import LinearSVC
from sklearn import preprocessing,svm
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, log_loss, precision_recall_fscore_support

# %% [markdown]
# ### Read CSV Files

# %%
train_df=pd.read_csv('UNSW_2018_IoT_Botnet_Final_10_best_Training.csv')
test_df=pd.read_csv('UNSW_2018_IoT_Botnet_Final_10_best_Testing.csv')

# %%
train_df
# Out:
#          pkSeqID proto            saddr  sport          daddr dport     seq  \
# 0        3142762   udp  192.168.100.150   6551  192.168.100.3    80  251984
# 1        2432264   tcp  192.168.100.150   5532  192.168.100.3    80  256724
# 2        1976315   tcp  192.168.100.147  27165  192.168.100.3    80   62921
# 3        1240757   udp  192.168.100.150  48719  192.168.100.3    80   99168
# 4        3257991   udp  192.168.100.147  22461  192.168.100.3    80  105063
# ...          ...   ...              ...    ...            ...   ...     ...
# 2934812  1132803   udp  192.168.100.149  56044  192.168.100.5    80  253370
# 2934813  3384621   udp  192.168.100.150  21546  192.168.100.3    80  231693
# 2934814   775893   udp  192.168.100.149  30897  192.168.100.5    80  158616
# 2934815   443484   tcp  192.168.100.147  36904  192.168.100.7    80  179855
# 2934816    96906   tcp  192.168.100.150  14302  192.168.100.3    80   95429
#
#            stddev  N_IN_Conn_P_SrcIP       min  state_number      mean  \
# 0        1.900363                100  0.000000             4  2.687519
# 1        0.078003                 38  3.856930             3  3.934927
# 2        0.268666                100  2.974100             3  3.341429
# 3        1.823185                 63  0.000000             4  3.222832
# 4        0.822418                100  2.979995             4  3.983222
# ...           ...                ...       ...           ...       ...
# 2934812  0.016992                100  4.082509             4  4.102515
# 2934813  1.922317                100  0.000000             4  2.718527
# 2934814  2.112228                100  0.000000             4  2.110766
# 2934815  0.000000                100  0.000000             3  0.000000
# 2934816  0.053820                100  0.064767             1  0.118588
#
#          N_IN_Conn_P_DstIP     drate     srate       max  attack category  \
# 0                      100  0.000000  0.494549  4.031619       1     DDoS
# 1                      100  0.000000  0.256493  4.012924       1     DDoS
# 2                      100  0.000000  0.294880  3.609205       1     DDoS
# 3                       63  0.000000  0.461435  4.942302       1      DoS
# 4                      100  0.000000  1.002999  4.994452       1     DDoS
# ...                    ...       ...       ...       ...     ...      ...
# 2934812                100  0.000000  0.243473  4.124047       1      DoS
# 2934813                100  0.000000  0.490800  4.090534       1     DDoS
# 2934814                100  0.000000  0.207444  4.332615       1      DoS
# 2934815                100  0.000000  0.162130  0.000000       1      DoS
# 2934816                100  0.038796  0.116388  0.172408       1      DoS
#
#         subcategory
# 0               UDP
# 1               TCP
# 2               TCP
# 3               UDP
# 4               UDP
# ...             ...
# 2934812         UDP
# 2934813         UDP
# 2934814         UDP
# 2934815         TCP
# 2934816         TCP
#
# [2934817 rows x 19 columns]

# %%
test_df
# Out:
#         pkSeqID proto            saddr  sport          daddr dport     seq  \
# 0        792371   udp  192.168.100.150  48516  192.168.100.3    80  175094
# 1       2056418   tcp  192.168.100.148  22267  192.168.100.3    80  143024
# 2       2795650   udp  192.168.100.149  28629  192.168.100.3    80  167033
# 3       2118009   tcp  192.168.100.148  42142  192.168.100.3    80  204615
# 4        303688   tcp  192.168.100.149   1645  192.168.100.5    80   40058
# ...         ...   ...              ...    ...            ...   ...     ...
# 733700  1571905   udp  192.168.100.148  17412  192.168.100.6    80  168162
# 733701  2787099   udp  192.168.100.147    932  192.168.100.3    80  158482
# 733702  2255382   tcp  192.168.100.149  47980  192.168.100.3    80   79841
# 733703   588946   tcp  192.168.100.147  25096  192.168.100.7    80   63165
# 733704  2577420   tcp  192.168.100.147  34718  192.168.100.3    80  139733
#
#           stddev  N_IN_Conn_P_SrcIP       min  state_number      mean  \
# 0       0.226784                100  4.100436             4  4.457383
# 1       0.451998                100  3.439257             1  3.806172
# 2       1.931553                 73  0.000000             4  2.731204
# 3       0.428798                 56  3.271411             1  3.626428
# 4       2.058381                100  0.000000             3  1.188407
# ...          ...                ...       ...           ...       ...
# 733700  1.743940                 39  0.000000             4  3.020449
# 733701  0.694618                 65  3.002272             4  3.905409
# 733702  1.744651                 53  0.000000             1  2.464288
# 733703  0.000000                100  0.000000             3  0.000000
# 733704  0.091420                 65  0.000000             3  0.052781
#
#         N_IN_Conn_P_DstIP     drate     srate       max  attack category  \
# 0                     100  0.000000  0.404711  4.719438       1      DoS
# 1                     100  0.225077  0.401397  4.442930       1     DDoS
# 2                     100  0.000000  0.407287  4.138455       1     DDoS
# 3                     100  0.000000  0.343654  4.229700       1     DDoS
# 4                     100  0.000000  0.135842  4.753628       1      DoS
# ...                   ...       ...       ...       ...     ...      ...
# 733700                 39  0.000000  0.224603  4.043432       1      DoS
# 733701                100  0.000000  0.875121  4.691634       1     DDoS
# 733702                100  0.278496  0.472773  3.802142       1     DDoS
# 733703                100  0.000000  0.070461  0.000000       1      DoS
# 733704                100  0.000000  0.093828  0.211125       1     DDoS
#
#        subcategory
# 0              UDP
# 1              TCP
# 2              UDP
# 3              TCP
# 4              TCP
# ...            ...
# 733700         UDP
# 733701         UDP
# 733702         TCP
# 733703         TCP
# 733704         TCP
#
# [733705 rows x 19 columns]

# %% [markdown]
# ### preprocessing

# %%
main_df=pd.concat([train_df,test_df])

# %%
main_df
# Out:
#         pkSeqID proto            saddr  sport          daddr dport     seq  \
# 0       3142762   udp  192.168.100.150   6551  192.168.100.3    80  251984
# 1       2432264   tcp  192.168.100.150   5532  192.168.100.3    80  256724
# 2       1976315   tcp  192.168.100.147  27165  192.168.100.3    80   62921
# 3       1240757   udp  192.168.100.150  48719  192.168.100.3    80   99168
# 4       3257991   udp  192.168.100.147  22461  192.168.100.3    80  105063
# ...         ...   ...              ...    ...            ...   ...     ...
# 733700  1571905   udp  192.168.100.148  17412  192.168.100.6    80  168162
# 733701  2787099   udp  192.168.100.147    932  192.168.100.3    80  158482
# 733702  2255382   tcp  192.168.100.149  47980  192.168.100.3    80   79841
# 733703   588946   tcp  192.168.100.147  25096  192.168.100.7    80   63165
# 733704  2577420   tcp  192.168.100.147  34718  192.168.100.3    80  139733
#
#           stddev  N_IN_Conn_P_SrcIP       min  state_number      mean  \
# 0       1.900363                100  0.000000             4  2.687519
# 1       0.078003                 38  3.856930             3  3.934927
# 2       0.268666                100  2.974100             3  3.341429
# 3       1.823185                 63  0.000000             4  3.222832
# 4       0.822418                100  2.979995             4  3.983222
# ...          ...                ...       ...           ...       ...
# 733700  1.743940                 39  0.000000             4  3.020449
# 733701  0.694618                 65  3.002272             4  3.905409
# 733702  1.744651                 53  0.000000             1  2.464288
# 733703  0.000000                100  0.000000             3  0.000000
# 733704  0.091420                 65  0.000000             3  0.052781
#
#         N_IN_Conn_P_DstIP     drate     srate       max  attack category  \
# 0                     100  0.000000  0.494549  4.031619       1     DDoS
# 1                     100  0.000000  0.256493  4.012924       1     DDoS
# 2                     100  0.000000  0.294880  3.609205       1     DDoS
# 3                      63  0.000000  0.461435  4.942302       1      DoS
# 4                     100  0.000000  1.002999  4.994452       1     DDoS
# ...                   ...       ...       ...       ...     ...      ...
# 733700                 39  0.000000  0.224603  4.043432       1      DoS
# 733701                100  0.000000  0.875121  4.691634       1     DDoS
# 733702                100  0.278496  0.472773  3.802142       1     DDoS
# 733703                100  0.000000  0.070461  0.000000       1      DoS
# 733704                100  0.000000  0.093828  0.211125       1     DDoS
#
#        subcategory
# 0              UDP
# 1              TCP
# 2              TCP
# 3              UDP
# 4              UDP
# ...            ...
# 733700         UDP
# 733701         UDP
# 733702         TCP
# 733703         TCP
# 733704         TCP
#
# [3668522 rows x 19 columns]

# %%
main_df.columns
# Out:
# Index(['pkSeqID', 'proto', 'saddr', 'sport', 'daddr', 'dport', 'seq', 'stddev',
#        'N_IN_Conn_P_SrcIP', 'min', 'state_number', 'mean', 'N_IN_Conn_P_DstIP',
#        'drate', 'srate', 'max', 'attack', 'category', 'subcategory'],
#       dtype='object')

# %%
ndf=main_df[['seq', 'stddev',
       'N_IN_Conn_P_SrcIP', 'min', 'state_number', 'mean', 'N_IN_Conn_P_DstIP',
       'drate', 'srate', 'max','attack', 'category']]

# %%
# ndf['category']=ndf['category'].astype('category')

# %%
# ndf.dtypes

# %% [markdown]
# ### extract features and class

# %%
X=ndf.iloc[:,:-2]
y=ndf.iloc[:,-1]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(y)
LabelEncoder()
print(list(le.classes_))
y = le.transform(y)
print(y)
# Out:
# ['DDoS', 'DoS', 'Normal', 'Reconnaissance', 'Theft']
# [0 0 0 ... 0 1 0]

# %% [markdown]
# ### train_test_split

# %%
import sklearn

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)

# %% [markdown]
# ### Model

# %%
# define the keras model
model = Sequential()
model.add(Dense(20, input_dim=10, activation='tanh'))
model.add(Dense(60, input_dim=20, activation='tanh'))
model.add(Dense(80, input_dim=60, activation='tanh'))
model.add(Dense(90, input_dim=80, activation='tanh'))
model.add(Dense(5, input_dim=90, activation='softmax'))
# model.add(Dense(80, input_dim=60, activation='relu'))
# model.add(Dense(80, input_dim=60, activation='relu'))
# model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 20)                220
# _________________________________________________________________
# dense_1 (Dense)              (None, 60)                1260
# _________________________________________________________________
# dense_2 (Dense)              (None, 80)                4880
# _________________________________________________________________
# dense_3 (Dense)              (None, 90)                7290
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 455
# =================================================================
# Total params: 14,105
# Trainable params: 14,105
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=10, batch_size=256)
# Out:
# Epoch 1/10
# 11465/11465 [==============================] - 14s 1ms/step - loss: 0.7928 - accuracy: 0.5194 - val_loss: 0.7866 - val_accuracy: 0.5264
# Epoch 2/10
# 11465/11465 [==============================] - 15s 1ms/step - loss: 0.7864 - accuracy: 0.5224 - val_loss: 0.7890 - val_accuracy: 0.5258
# Epoch 3/10
# 11465/11465 [==============================] - 15s 1ms/step - loss: 0.7882 - accuracy: 0.5237 - val_loss: 0.7874 - val_accuracy: 0.5264
# Epoch 4/10
# 11465/11465 [==============================] - 15s 1ms/step - loss: 0.7880 - accuracy: 0.5226 - val_loss: 0.7870 - val_accuracy: 0.5260
# Epoch 5/10
# 11465/11465 [==============================] - 15s 1ms/step - loss: 0.7872 - accuracy: 0.5223 - val_loss: 0.7868 - val_accuracy: 0.5264
# Epoch 6/10
# 11465/11465 [==============================] - 15s 1ms/step - loss: 0.7869 - accuracy: 0.5228 - val_loss: 0.7802 - val_accuracy: 0.5262
# Epoch 7/10
# 11465/11465 [==============================] - 15s 1ms/step - loss: 0.7908 - accuracy: 0.5217 - val_loss: 0.7860 - val_accuracy: 0.5265
# Epoch 8/10
# 11465/11465 [==============================] - 14s 1ms/step - loss: 0.7867 - accuracy: 0.5225 - val_loss: 0.7871 - val_accuracy: 0.5262
# Epoch 9/10
# 11465/11465 [==============================] - 15s 1ms/step - loss: 0.7871 - accuracy: 0.5223 - val_loss: 0.7845 - val_accuracy: 0.5263
# Epoch 10/10
# 11465/11465 [==============================] - 15s 1ms/step - loss: 0.7878 - accuracy: 0.5225 - val_loss: 0.7841 - val_accuracy: 0.5269

# %%
# model.fit(X, y,  epochs=10, batch_size=10)
