# %% [markdown]
# ## import libraries

# %% [markdown]
# - stop displaying of warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# - import libraries

# %%
#Neural network module
import tensorflow as tf
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense,Activation,Dropout 
from tensorflow.keras.layers import BatchNormalization 
from tensorflow.keras.utils import to_categorical
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5692/1133275132.py in <module>
#       1 #Neural network module
# ----> 2 import tensorflow as tf
#       3 from tensorflow.keras.models import Sequential
#       4 from tensorflow.keras.layers import Dense,Activation,Dropout
#       5 from tensorflow.keras.layers import BatchNormalization
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import pandas as pd
import glob
import os

import re
import string
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics
import math

from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report, accuracy_score,precision_score, recall_score, f1_score

pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# ## Read Data
#
# - read dataset that we join in the last file
# - display first 20 samples for demo purpose

# %%
df1 = pd.read_csv("data/train.csv")
df2 = pd.read_csv('data/test.csv')

print("\n\nSample Data:")
print("============\n")
print(df1.head(20))
# Out:
# Sample Data:
# ============
#
#     kurtosis  kurtosis.1  kurtosis.2  kurtosis.3  kurtosis.4  kurtosis.5  \
# 0   1.000000    2.000000    3.000000    4.000000    5.000000    6.000000
# 1   3.856789    1.541901    0.000816    0.330728    0.118731   -0.342687
# 2   2.624517    2.415293    0.440233   -0.782131   -0.771069   -0.724216
# 3   5.076893    1.161854    2.095651    1.372743   -0.203574   -0.345354
# 4   0.384906    1.203378    0.429393    0.639471   -0.080144   -0.440946
# 5  -0.038922    4.771146   -0.378949   -0.309047   -0.661308   -0.531602
# 6   3.482526    6.999774    1.099179    1.374592    0.082182   -0.034641
# 7   1.072971    2.509553   -0.457227    0.762923    0.649274   -0.132112
# 8   3.531016   11.265465    0.271847   -0.330451    0.411697    0.451828
# 9  -0.536755    0.878468   -1.036644    0.084539    2.263659   -0.331764
# 10  4.415954    4.862323    1.503381    1.816249   -0.340376    1.006949
# 11 -0.585046    1.401965   -0.288332    0.786538    0.224412   -0.069836
# 12  2.091314    2.347621   -0.258641    0.005461   -0.393147   -0.181086
# 13 -0.728076   -0.619696   -0.552621    0.250954    0.750192   -0.397720
# 14  4.688147    7.003437    0.106896    0.359553   -0.362381   -0.425448
# 15  0.542011    0.696471   -0.030343    0.393337   -0.244836   -0.060111
# 16  0.775228    1.873175    0.475450    0.089207   -0.097638   -0.272024
# 17 -0.889710    1.393579   -0.990197   -0.799590    0.437371    0.061176
# 18  2.212805    4.718198    1.230358   -0.127880   -0.230437    0.119820
# 19  2.860622    0.766592    0.273849   -0.479223    0.224462   -0.191169
#
#     kurtosis.6  kurtosis.7  kurtosis.8  kurtosis.9  kurtosis.10  kurtosis.11  \
# 0     7.000000    8.000000    9.000000   10.000000    11.000000    12.000000
# 1    -0.259252    0.146735    0.410656   -0.162872    -0.029920     0.430621
# 2     0.090260    0.152119    0.261731   -0.608905     0.096892    -0.248479
# 3    -0.529139    0.561974    0.281350   -0.150672    -0.051230    -0.189193
# 4    -0.432567   -0.126163    0.507695    0.408915     0.024341     0.113680
# 5     0.029186    0.662524   -0.084562    0.965640     0.199449    -0.041373
# 6     0.470437    0.012439    0.079167    0.129734     0.097393     0.092738
# 7     0.732638   -0.240707   -0.050426    0.556773     0.573582     0.314016
# 8     0.508565   -0.234395    0.610929    1.694304     0.245849     0.300705
# 9    -0.404102    0.035749   -0.587463   -0.099014     0.005201     0.284375
# 10    0.925204    0.066775    0.683684    0.805832     2.509903     0.477833
# 11    0.281334    0.677087    0.209738    0.130731     0.074730     0.396269
# 12   -0.104094    0.191442    0.111956    0.026635     0.436664     0.385919
# 13   -0.057406   -0.204402   -0.387839    0.011538     0.975144     1.614142
# 14   -0.140424   -0.121623    0.717900    0.624571     0.250457     0.226507
# 15   -0.072772    0.369807   -0.151172    0.251898     0.383935    -0.034633
# 16    0.224655    0.130583   -1.054132   -0.492533    -0.499878    -0.398058
# 17    0.158364   -0.489816    0.283048    0.011335     0.089267     0.287547
# 18    0.569723    0.082410    0.217840    0.594542     1.030378     0.703378
# 19    1.379421    0.091784   -0.147663    0.080536    -0.048812     0.266947
#
#     kurtosis.12  kurtosis.13  kurtosis.14  kurtosis.15  kurtosis.16  \
# 0     13.000000    14.000000    15.000000    16.000000    17.000000
# 1     -0.225081    -0.303092    -0.190764    -0.052871    -0.151794
# 2      0.159848     0.637849     0.192881     0.286125    -0.066113
# 3      0.024108     0.111374     0.178489    -0.124275    -0.031861
# 4     -0.160073     0.272321     0.280109     0.434392    -0.011030
# 5     -0.062308    -0.122510    -0.096526     0.042070     0.446569
# 6      0.136591     0.039005    -0.013402    -0.042872    -0.201744
# 7      0.435108     0.722288     1.989071     2.463858     1.115127
# 8      0.013861    -0.093748     0.150476     0.407268     0.327096
# 9      0.502275     0.697826     0.850343     0.211855     0.261614
# 10     0.470431    -0.140807     0.488149     1.786065     0.545542
# 11     0.418090     0.591765     0.160098    -0.078267     0.064682
# 12     0.330969     0.401702     0.044223     0.022726     0.519177
# 13     1.936126     3.298345     1.536727     1.339437     2.132262
# 14     0.198828     0.513999     0.369560     0.415636     0.143940
# 15     0.060181     0.409882     0.770385     0.352355     0.275292
# 16    -0.339775    -0.120302     0.595144    -0.036814     0.105365
# 17    -0.045668     0.173075     0.953678     0.211094    -0.256754
# 18     0.508167     0.438553     1.631135     2.158601     1.230336
# 19     0.332530     0.062015     0.311248     0.292468     0.157899
#
#     kurtosis.17  kurtosis.18  kurtosis.19        max       max.1       max.2  \
# 0     18.000000    19.000000    20.000000   1.000000    2.000000    3.000000
# 1     -0.000590     0.075492     0.002595  28.657707  215.541351   52.424423
# 2      0.363365     0.614379     0.131038 -40.500740  218.972977   50.373932
# 3     -0.154391     0.105716     0.043984  20.196968  235.198517   60.412815
# 4      0.454063     0.653689     0.788133 -19.554893  218.817322   95.971344
# 5      0.446622     0.083110     0.150460 -31.971275  232.621674   78.805496
# 6     -0.012869    -0.262601    -0.011853 -20.864298  202.289368   40.374004
# 7      2.435659     1.935996     1.636979 -13.648316  235.648727   49.441505
# 8      0.411722     0.510247     1.213895 -71.784760  228.464325   61.611286
# 9      0.760615     1.927444     1.446667 -85.252228  219.761627   72.776283
# 10     0.581778     0.338935     1.581731   8.973942  207.947174   50.190922
# 11    -0.137568    -0.301568     0.549481   8.405069  206.690720   79.449425
# 12     0.204323     0.802741     1.654232 -12.447734  236.499359   74.834221
# 13     3.573942     3.702959     3.538665 -83.479996  242.034012   83.913383
# 14     0.836082     5.926496    11.114108 -25.297148  206.325317   45.150784
# 15     0.207698     0.310406     0.567391  23.986458  224.780808   64.606148
# 16     0.270467     0.249148     0.072354  35.041653  240.678116   93.041145
# 17     0.306995     0.151538     0.194358  33.071178  246.289886   81.886086
# 18     0.733893     0.645266     0.930800 -59.530540  267.088379  118.687141
# 19     0.360819     0.024073     0.135267  54.587170  246.927124   44.665428
#
#          max.3      max.4      max.5      max.6      max.7      max.8  \
# 0     4.000000   5.000000   6.000000   7.000000   8.000000   9.000000
# 1   103.289833  54.599335  85.158218  37.843021  58.169933  30.032066
# 2   112.312531  51.513710  66.547562  29.266182  57.987415  48.333500
# 3    78.466721  52.209972  58.236206  21.597277  42.955067  27.950972
# 4   148.336426  76.376114  89.940414  41.089226  51.864899  38.256203
# 5   108.459908  70.781197  71.766411  37.780437  50.200264  40.300247
# 6    83.999069  48.548840  46.266743  18.049488  23.073051  22.538765
# 7   109.014771  45.224102  59.254532  32.666122  28.733267  27.568384
# 8    86.390579  40.442608  48.777710  25.781929  30.106419  25.424322
# 9    69.626251  49.926189  30.486677  29.701012  27.753103  26.347588
# 10   93.233696  51.422779  41.034500  23.231037  34.639454  22.473415
# 11   91.186752  44.244873  45.519428  22.075005  35.621147  19.582556
# 12  101.966850  43.632023  60.192204  24.197357  36.297157  22.703812
# 13   64.636963  42.412533  21.775572  19.829430  27.165495  32.176865
# 14   78.819908  41.847855  41.292999  19.069883  24.786531  27.454573
# 15   85.572716  40.894192  41.832729  24.147030  27.285875  21.319632
# 16  121.625984  60.597820  62.775345  38.241985  51.670364  48.489895
# 17   98.401901  51.398872  55.034229  26.300579  40.683472  37.644665
# 18   89.304596  51.158707  36.595188  41.593884  29.031286  27.560305
# 19   80.899681  69.410927  59.207886  37.226341  51.072929  22.977655
#
#         max.9     max.10     max.11     max.12     max.13     max.14  \
# 0   10.000000  11.000000  12.000000  13.000000  14.000000  15.000000
# 1   39.129414  27.737400  37.241585  34.146088  33.541115  30.837498
# 2   43.876404  27.197964  32.226604  37.523643  35.240238  45.277225
# 3   36.474834  24.780317  36.499405  17.194538  27.241575  22.876415
# 4   30.776117  44.689346  27.681576  34.421986  37.344429  49.565659
# 5   24.080669  43.663872  25.094612  39.443817  26.323229  23.582724
# 6   20.979940  20.788670  21.676950  17.197134  19.139555  38.012703
# 7   28.791237  20.879009  23.705938  20.156172  24.469431  41.208752
# 8   24.462221  20.214090  28.682066  12.631783  20.710623  29.524267
# 9   17.189814  23.417694  17.823446  24.767927  23.924730  24.341755
# 10  23.620581  22.256878  19.833433  16.981649  21.237883  29.356470
# 11  23.202320  26.371367  31.898468  37.461353  33.444611  32.216190
# 12  33.341003  19.905172  31.416674  21.023390  33.588894  36.066963
# 13  26.547010  30.051342  25.638800  38.091709  45.342484  44.589558
# 14  21.341894  21.013107  24.843979  15.686235  24.644499  24.994062
# 15  26.706945  17.967314  19.167013  18.810322  16.847582  30.654751
# 16  32.395267  39.653870  30.486458  31.909634  25.354265  29.587782
# 17  36.294685  26.326046  30.143208  24.214535  27.054625  28.152996
# 18  25.370035  32.131836  25.823925  32.889278  27.612267  34.345371
# 19  36.519531  35.951626  35.162109  27.274580  32.306683  25.911734
#
#        max.15     max.16     max.17     max.18     max.19        mean  \
# 0   16.000000  17.000000  18.000000  19.000000  20.000000    1.000000
# 1   28.613127  32.683372  22.623711  27.038391  21.427813 -163.772964
# 2   33.539673  31.718861  30.777176  36.514858  24.971487 -205.440491
# 3   28.581476  26.515833  22.581646  21.727827  24.471794 -135.864822
# 4   33.491501  27.266478  39.183495  41.201622  48.356075 -225.713318
# 5   26.908339  28.237724  34.481903  34.141266  40.524857 -253.143906
# 6   32.479836  27.478825  34.554661  28.890615  24.913008 -198.270508
# 7   52.334015  40.133514  43.998146  39.895744  35.629257 -247.091751
# 8   17.914921  20.745771  27.886328  25.284472  33.080357 -236.168671
# 9   24.839653  25.340700  24.666035  27.416409  28.633955 -362.078461
# 10  26.189203  26.321188  29.617065  23.127378  35.012169 -186.514740
# 11  44.569706  44.472927  44.266872  50.616825  51.334209 -275.954010
# 12  32.173145  29.632048  34.499275  31.376329  42.252495 -180.558411
# 13  40.297295  35.524834  45.348076  36.954315  39.814453 -382.327240
# 14  22.673031  16.377800  29.627707  46.204887  62.045704 -188.322769
# 15  23.115747  26.163311  28.625687  27.699301  42.266075 -194.506424
# 16  24.520304  23.529737  31.800236  29.009098  38.006855 -191.603226
# 17  20.878792  21.109861  27.596207  27.519821  26.083839 -225.908798
# 18  39.446125  37.863220  33.518787  27.471542  29.021795 -240.034256
# 19  30.365253  21.540981  32.435760  20.103901  20.322374  -68.950661
#
#         mean.1     mean.2     mean.3     mean.4     mean.5     mean.6  \
# 0     2.000000   3.000000   4.000000   5.000000   6.000000   7.000000
# 1   116.696678 -41.753826  29.144329 -15.050158  18.879372  -8.918165
# 2   132.215073 -16.085823  41.514759  -7.642954  16.942802  -5.651261
# 3   157.040085 -53.453247  17.198896   6.868035  13.934344 -11.749298
# 4   139.332825 -13.097699  44.533356   2.468400  28.328743  -9.931481
# 5   155.716324 -16.636627  23.683815   6.045957  11.692952  -9.947761
# 6   149.596085 -33.988358  24.394318  -1.710330  -1.225932 -10.032828
# 7   169.054779 -32.878578  27.442389   4.231593   3.658492  -3.239693
# 8   176.961121 -37.586685  25.964237   4.480114  -1.263420  -1.683040
# 9   140.542358   9.491833   7.825447   9.826683  -1.148198  -3.773265
# 10  147.317108 -39.110840  24.590965   9.532658  -3.753717  -3.437393
# 11  133.400314   0.223952  14.811478  -6.008891  -5.081825 -18.553179
# 12  159.271988 -14.024701  19.899075  -4.689734  16.504417  -9.619870
# 13  137.106522  16.190987   9.170871   9.428531  -1.769179  -2.799351
# 14  157.294266 -32.621510  16.180454  -0.251562   2.885064  -8.676029
# 15  152.922623 -22.887516  12.650760  -6.497721  -3.656916 -12.266700
# 16  146.538330 -13.940589  38.911240 -15.132569  18.394884  -5.414647
# 17  159.112701   4.835047  23.729975   3.456676   9.158143  -9.201875
# 18  197.234833 -11.008194  11.837275  -1.179668  -2.441559   6.362208
# 19  159.996567 -52.393383  26.487968   8.450644  15.509462 -11.053805
#
#        mean.7     mean.8     mean.9    mean.10    mean.11    mean.12  \
# 0    8.000000   9.000000  10.000000  11.000000  12.000000  13.000000
# 1   12.002118  -4.253151   1.359791  -2.683000  -0.794632  -6.920971
# 2    9.569445   0.503157   8.673513  -8.271377   0.594473  -0.340203
# 3    8.360711  -5.130381   0.233845  -5.421206   1.679479  -6.218249
# 4   10.810857   3.002879  -0.937692   7.138268  -6.625260   0.824269
# 5    6.887814  -3.273322  -6.340906   7.602782  -5.851329   2.017422
# 6  -13.955785  -8.545691 -10.279505 -10.899047  -6.837952 -10.596197
# 7   -3.844271  -7.041083  -4.851360  -7.777618  -5.300612  -7.811625
# 8   -7.309591  -3.094484  -8.068974  -8.639774  -6.337066  -7.523060
# 9   -6.087869  -6.032640  -6.716433  -6.756777  -5.620542  -6.113682
# 10  -4.848540  -5.757183  -4.280905  -7.076722  -7.065862  -9.024330
# 11 -12.985694 -13.947026 -13.310711 -15.994515 -10.130820 -11.950521
# 12  -4.912070 -11.798516  -8.316737 -10.977398  -4.597470  -8.597732
# 13  -2.452653  -2.991112  -5.300632  -5.607359  -2.904100  -2.091456
# 14  -7.969428  -5.203082  -6.120501  -9.026099  -7.145565  -8.257332
# 15 -10.156269 -10.590389 -12.074541 -19.933239 -11.008598  -9.658095
# 16  -4.742973   5.958301 -12.462138  -2.633181 -10.058628   1.083780
# 17  -2.744054  -1.576588   2.179896  -3.458968  -4.684260  -6.594335
# 18  -2.125107  -1.088729  -3.747200  -4.121510  -1.449666   1.212831
# 19  11.630246  -5.043081  10.690701  -0.002446   3.648237  -0.808390
#
#       mean.13    mean.14    mean.15    mean.16    mean.17    mean.18  \
# 0   14.000000  15.000000  16.000000  17.000000  18.000000  19.000000
# 1   -3.655366   1.465213   0.201078   3.998204  -2.114676   0.116842
# 2    2.377888   7.899487   1.947641   7.441950  -1.739911   0.278015
# 3    1.844195  -4.099704   0.779950  -0.559577  -1.018324  -3.807545
# 4   -2.003132   4.293943  -7.935050   0.063948  -2.363509  -0.158602
# 5   -4.396296  -3.689521  -0.929987   0.783247   0.768126   2.809321
# 6   -9.231290  -2.515348  -7.065397  -5.166757  -4.082373  -7.186882
# 7   -8.249811  -4.028747  -4.829070  -5.325627  -4.919715  -6.058657
# 8   -5.852493  -3.871484  -7.844690  -7.812194  -6.285968  -5.260286
# 9   -6.682680  -4.767138  -4.243054  -8.594221 -10.304626  -7.124259
# 10  -8.604538  -2.838094  -5.910635  -9.073384  -4.644867  -5.814669
# 11 -13.994747  -6.439019  -1.626236   0.564000   2.747948   0.124077
# 12  -6.082945  -3.752255 -11.180609  -5.955894   0.502858  -9.136359
# 13  -3.341296  -3.756197  -5.785854  -8.870886  -7.401326  -4.650372
# 14  -6.265422  -3.952569  -8.824435  -8.623124  -3.937507  -5.595484
# 15 -10.165163  -6.070020  -9.144890  -9.608690  -2.066154  -5.645410
# 16  -4.286447  -0.948913  -2.989625  -3.441096   0.976290   1.426765
# 17  -4.595904  -4.976099  -6.670098 -11.068754  -8.379526  -2.998730
# 18  -2.780679  -2.919077  -1.012778  -3.329338  -0.589737  -1.658856
# 19   4.593976   2.042797   3.715303  -0.922246   2.256301  -1.801516
#
#       mean.19      median    median.1   median.2   median.3      median.4  \
# 0   20.000000    1.000000    2.000000   3.000000   4.000000  5.000000e+00
# 1   -5.785884 -143.594299  124.859314 -43.518631  28.886786 -1.349991e+01
# 2   -5.489016 -181.015961  138.253937 -14.507562  43.082825 -7.996415e+00
# 3   -0.679533 -113.085472  162.577866 -59.372467  18.395090  5.167327e+00
# 4    0.594098 -200.058487  151.323730 -17.983593  44.273613  2.577760e+00
# 5    3.325740 -259.161804  162.363647 -23.059948  22.198856  8.053862e+00
# 6   -6.407996 -198.137833  156.257309 -33.818821  23.721470  2.123726e-01
# 7   -4.577196 -230.792923  185.680542 -34.084515  26.844696  6.082856e+00
# 8   -4.737786 -224.039978  183.819794 -42.293331  27.116432  6.404188e+00
# 9   -6.203530 -361.054077  153.187988  11.043562   6.454574  1.043066e+01
# 10  -2.774010 -181.966522  160.835220 -39.674435  23.545462  1.168410e+01
# 11   1.466067 -286.351349  140.876328   2.269311  13.337073 -3.843168e+00
# 12   0.052439 -171.808228  169.665802 -14.063411  18.126352 -3.917871e+00
# 13  -5.852079 -388.434418  146.728989  15.582011   6.896252  9.663803e+00
# 14  -1.126706 -185.976715  166.184830 -34.539421  14.475735  2.220446e-14
# 15  -1.899368 -181.448044  162.499573 -26.625090  11.719124 -5.975899e+00
# 16  -0.516994 -173.746536  149.069763 -16.906347  41.292553 -1.479557e+01
# 17  -0.961959 -247.482346  169.893692   5.287713  24.691166  3.637650e+00
# 18  -4.410829 -214.926971  214.071182 -16.287836  10.000671 -8.432751e-02
# 19  -2.051700  -38.188251  156.785278 -53.820774  28.466436  5.094159e+00
#
#         median.5   median.6   median.7   median.8   median.9  median.10  \
# 0   6.000000e+00   7.000000   8.000000   9.000000  10.000000  11.000000
# 1   1.918167e+01  -7.834178  11.582661  -3.643022   1.085177  -2.272115
# 2   1.744389e+01  -3.931509   9.787046   0.266423   8.910020  -7.978985
# 3   1.509271e+01 -12.179042   9.030704  -4.417754   0.402256  -5.511658
# 4   2.891986e+01 -11.038717  10.553270   3.042562   0.020442   6.945658
# 5   1.394890e+01  -9.057709   5.989365  -3.474609  -5.726287   7.370381
# 6  -1.541060e+00  -8.456752 -14.365665  -8.224062  -9.864245 -10.616151
# 7   2.522826e+00  -2.183037  -3.164749  -7.153724  -4.813126  -7.546540
# 8  -1.691448e+00  -0.669329  -7.742576  -2.975410  -8.338515  -8.810980
# 9  -7.801990e-01  -3.831190  -5.358436  -6.045767  -6.056417  -6.792227
# 10 -5.077271e+00  -1.384912  -5.625128  -4.935551  -3.364728  -6.129397
# 11 -6.072808e+00 -18.594643 -13.625436 -13.031731 -12.966051 -15.694230
# 12  1.639668e+01  -9.155787  -4.960860 -11.761856  -9.132164 -10.641138
# 13 -2.486900e-14  -1.834036  -0.928845  -1.610939  -4.664259  -5.962648
# 14  2.380457e+00  -6.893342  -7.495306  -4.881826  -5.719873  -8.541118
# 15 -4.094258e+00 -12.163051 -10.057003 -10.844617 -11.291344 -19.962837
# 16  2.211766e+01  -4.944422  -6.208043   6.502182 -13.432387  -2.184506
# 17  9.703372e+00  -9.401495  -4.352034  -1.680209   1.800481  -3.607838
# 18 -2.019972e+00   6.505912  -1.725960  -0.679056  -3.353800  -3.640417
# 19  1.691017e+01 -11.796144  11.046741  -5.320596  11.159194  -0.800367
#
#     median.11  median.12  median.13  median.14  median.15  median.16  \
# 0   12.000000  13.000000  14.000000  15.000000  16.000000  17.000000
# 1   -0.952252  -6.490981  -3.207944   1.109259   0.027717   3.859897
# 2    0.260834  -0.112727   2.252367   7.514513   1.874906   7.339341
# 3    1.437656  -5.885943   1.785256  -3.712467   0.426583  -0.346940
# 4   -6.841835   0.789223  -2.074976   4.267029  -8.258801   0.106150
# 5   -5.961611   2.180347  -3.762003  -3.057094  -0.654292   1.140368
# 6   -7.011565 -10.733818  -9.040432  -2.690603  -7.510866  -5.609499
# 7   -5.735576  -7.889843  -8.419559  -4.154808  -4.654626  -5.766350
# 8   -6.642427  -7.156420  -5.341886  -4.276130  -7.544528  -7.873323
# 9   -5.784051  -6.283421  -6.818441  -4.947080  -4.862559  -8.686833
# 10  -6.844070  -8.889655  -9.075652  -2.581332  -4.915079  -9.073297
# 11 -10.309852 -12.415252 -14.355699  -6.688718  -2.636160  -0.261209
# 12  -4.765490  -8.393882  -6.197631  -4.565335 -10.562372  -5.914163
# 13  -2.939282  -2.372949  -2.997527  -3.800485  -5.682404  -9.198926
# 14  -7.159477  -7.985436  -6.086131  -3.772140  -8.573628  -8.951509
# 15 -11.251981  -9.396883  -9.500242  -6.086201  -8.499179  -9.514863
# 16 -10.571538   1.434256  -3.906214  -0.550741  -2.709833  -3.327323
# 17  -5.164671  -6.787000  -5.007681  -5.088086  -6.946511 -11.530775
# 18  -1.034181   0.720206  -2.825941  -2.969877  -1.130753  -3.140855
# 19   3.496829  -0.835399   4.405321   1.933659   3.680773  -0.713837
#
#     median.17     median.18  median.19         min         min.1       min.2  \
# 0   18.000000  1.900000e+01  20.000000    1.000000  2.000000e+00    3.000000
# 1   -1.698104  1.509903e-14  -5.589337 -504.891144 -1.421085e-14 -115.315613
# 2   -1.918201  1.598721e-14  -5.602306 -528.702759 -6.228398e+01  -87.205124
# 3   -0.935113 -3.773196e+00  -0.470251 -537.587097  5.151435e-14 -130.033524
# 4   -2.480051 -3.105032e-02   0.269768 -534.102905 -2.451428e+01  -91.350792
# 5    0.658980  2.238576e+00   2.341137 -537.719177 -2.868577e+01  -88.630844
# 6   -3.892550 -7.585949e+00  -6.669068 -504.201080 -8.571437e+00  -89.612144
# 7   -5.272299 -6.075992e+00  -4.669431 -589.865723 -3.969534e+01  -97.862061
# 8   -6.374492 -5.374257e+00  -5.127306 -562.680725 -5.773160e-14  -87.915924
# 9  -10.618515 -7.572069e+00  -6.826773 -544.546753 -2.220446e-14  -89.181023
# 10  -5.300006 -5.352282e+00  -3.107978 -476.499481  2.930989e-14 -103.816986
# 11   2.091719 -1.193698e+00   0.031243 -521.233093 -4.243750e+00 -101.009598
# 12   0.266376 -9.128393e+00  -0.664980 -559.833618 -3.097790e+01  -80.843811
# 13  -8.510858 -5.217793e+00  -6.455961 -552.654968  1.598721e-14  -90.818718
# 14  -4.822231 -6.078460e+00  -2.201971 -496.502838 -2.042810e-14  -78.651688
# 15  -1.872214 -5.903346e+00  -2.338780 -498.662964 -3.819167e-14  -82.516029
# 16   1.209806  1.453249e+00  -0.973117 -536.566467 -2.258582e+01 -107.670578
# 17  -8.737462 -3.071439e+00  -0.970262 -507.702026 -2.126527e+01  -83.674690
# 18  -0.573233 -1.650417e+00  -4.532031 -536.904907 -2.220446e-14  -85.226181
# 19   2.182373 -1.624485e+00  -2.145388 -506.832367  1.154632e-14 -114.359787
#
#         min.3      min.4      min.5      min.6      min.7      min.8  \
# 0    4.000000   5.000000   6.000000   7.000000   8.000000   9.000000
# 1  -51.569004 -97.879890 -41.524628 -61.748718 -39.678986 -54.222973
# 2  -24.319845 -74.060310 -30.447651 -59.320251 -33.444458 -38.407055
# 3  -50.578659 -45.113949 -45.514446 -44.849060 -43.018734 -44.329350
# 4  -19.489414 -60.867123 -18.178022 -68.356682 -29.519875 -33.470188
# 5  -48.062416 -65.231674 -37.055840 -58.395340 -29.532084 -31.794376
# 6  -41.787010 -66.639030 -35.269325 -60.507267 -48.936970 -40.540474
# 7  -24.638981 -69.389694 -32.752907 -50.071907 -43.322491 -42.978058
# 8  -21.081821 -59.894863 -40.072792 -48.778267 -39.101646 -34.418499
# 9  -42.121326 -56.278332 -39.417553 -38.819969 -47.538612 -36.337887
# 10 -24.070385 -52.285534 -35.315044 -42.115345 -43.212601 -42.053211
# 11 -56.189781 -70.668091 -46.065517 -61.604752 -55.478813 -58.835320
# 12 -35.751366 -68.388077 -33.708687 -63.001637 -44.028477 -50.105053
# 13 -48.236366 -50.897484 -41.100159 -35.851440 -36.361862 -33.596645
# 14 -39.053490 -61.532078 -40.290752 -46.912800 -38.527073 -41.121372
# 15 -38.953636 -72.462494 -53.212963 -51.828991 -52.092743 -47.026207
# 16 -29.396942 -76.616730 -37.216141 -49.901257 -66.858742 -38.854057
# 17 -39.241867 -67.858749 -38.024620 -48.608067 -35.214005 -46.230640
# 18 -51.282059 -43.922729 -41.247364 -30.626150 -30.538177 -33.124748
# 19 -27.338045 -48.941700 -28.575268 -56.724003 -28.022156 -40.416962
#
#         min.9     min.10     min.11     min.12     min.13     min.14  \
# 0   10.000000  11.000000  12.000000  13.000000  14.000000  15.000000
# 1  -42.562126 -49.195107 -35.534348 -38.507935 -33.411980 -31.206163
# 2  -26.083885 -46.700871 -35.248055 -33.570656 -34.795387 -22.939646
# 3  -40.170555 -33.503983 -27.465820 -35.827618 -27.609230 -31.050648
# 4  -46.247433 -30.817661 -37.979633 -31.480433 -32.252655 -29.677416
# 5  -51.991615 -27.577976 -37.515942 -29.097752 -33.879478 -43.214520
# 6  -48.595013 -46.611736 -37.645298 -44.284595 -43.032810 -31.864069
# 7  -41.313057 -42.452671 -35.398045 -37.943367 -40.834217 -28.668577
# 8  -50.099407 -36.438160 -29.277153 -34.310898 -30.372746 -27.866802
# 9  -47.141834 -32.025654 -28.076738 -29.914595 -39.010693 -42.924931
# 10 -39.317062 -47.426571 -38.204266 -39.691441 -38.117687 -33.456455
# 11 -55.203510 -58.630608 -42.376072 -41.556660 -52.739681 -43.335285
# 12 -47.479027 -50.227699 -42.281738 -44.890667 -41.359894 -41.493919
# 13 -40.600616 -28.195665 -29.120504 -32.563107 -33.752243 -33.350891
# 14 -40.800529 -39.620411 -38.720306 -43.051636 -44.029648 -32.828442
# 15 -54.018669 -55.612831 -42.752914 -36.113266 -47.472916 -41.344204
# 16 -55.643837 -49.574703 -40.894386 -36.443424 -38.705059 -35.769768
# 17 -33.079090 -30.012966 -37.617840 -30.164356 -34.494194 -41.139736
# 18 -40.445023 -43.307919 -34.848381 -24.246473 -24.714592 -29.730520
# 19 -29.566715 -35.782154 -26.513180 -24.204132 -21.708410 -26.128771
#
#        min.15     min.16     min.17     min.18     min.19      skew    skew.1  \
# 0   16.000000  17.000000  18.000000  19.000000  20.000000  1.000000  2.000000
# 1  -32.890686 -28.135849 -32.310982 -27.950054 -34.325916 -1.747327 -1.189495
# 2  -33.812237 -20.736326 -29.763596 -37.071568 -30.421646 -1.488152 -1.258937
# 3  -29.610868 -24.419205 -27.490347 -31.339273 -25.615374 -2.146357 -0.948269
# 4  -38.244465 -29.149513 -32.482296 -29.378662 -28.567430 -0.983664 -1.251729
# 5  -31.253214 -36.442825 -32.249405 -26.747944 -27.527420 -0.449279 -1.935523
# 6  -44.889545 -34.202045 -34.704933 -40.382065 -37.972187 -1.200593 -2.421386
# 7  -37.237728 -35.696278 -35.713699 -33.304691 -34.484638 -0.917394 -1.712221
# 8  -36.060226 -33.081226 -34.194088 -34.075012 -34.361206 -1.471997 -2.959909
# 9  -28.526848 -36.170849 -37.754906 -32.720425 -25.959482  0.160517 -1.127583
# 10 -45.313221 -41.991844 -26.329885 -43.281044 -27.276802 -1.887822 -2.317791
# 11 -41.166309 -42.889721 -37.076199 -42.383781 -35.988670  0.174483 -1.182531
# 12 -50.145061 -42.186401 -30.173613 -46.253452 -32.833416 -0.823122 -1.487154
# 13 -38.953285 -35.893295 -35.737984 -33.272045 -37.862381  0.263697 -0.577456
# 14 -43.635494 -36.301849 -30.872988 -38.014103 -28.037298 -1.454483 -2.419144
# 15 -42.789501 -36.977306 -35.550720 -36.791401 -30.182358 -0.791344 -0.910958
# 16 -34.108833 -33.622360 -39.475636 -28.283010 -26.431097 -0.889738 -0.836739
# 17 -46.240063 -37.280159 -34.291172 -28.152388 -24.145645  0.050432 -1.268284
# 18 -30.475733 -30.524881 -21.965248 -24.948616 -30.509811 -1.541592 -2.142407
# 19 -26.860077 -25.843300 -24.987009 -25.349009 -20.818214 -1.887806 -0.033511
#
#       skew.2    skew.3    skew.4    skew.5    skew.6    skew.7    skew.8  \
# 0   3.000000  4.000000  5.000000  6.000000  7.000000  8.000000  9.000000
# 1   0.320707  0.043292 -0.262969  0.031747 -0.272285  0.073492 -0.165036
# 2  -0.360284 -0.108640  0.015386  0.037464 -0.511768 -0.019643 -0.047712
# 3   1.330144 -0.561734  0.199589 -0.327581  0.032935 -0.517675 -0.318736
# 4   0.753546  0.241620 -0.020761 -0.038195  0.046983  0.130045 -0.061351
# 5   0.582460  0.054805 -0.228474 -0.320816 -0.378186  0.359567  0.221628
# 6   0.431475  0.471721 -0.405517  0.303566 -0.732623  0.199341 -0.238249
# 7   0.351920  0.614771 -0.793360  0.422506 -0.531354 -0.235709 -0.053737
# 8   0.773335  0.007311 -0.625297  0.437070 -0.475175  0.072334 -0.157970
# 9  -0.356514  0.272929 -0.865592 -0.304795 -0.178236 -0.475685 -0.157484
# 10  0.519048  0.718944 -0.484351  0.798151 -0.923139  0.328773 -0.502069
# 11 -0.385261  0.341557 -0.534609  0.291335  0.012601  0.424488 -0.459435
# 12  0.197838  0.484901 -0.306060 -0.001916 -0.240268  0.052510 -0.037250
# 13 -0.255593  0.406739 -0.571211 -0.484563 -0.432863 -0.315450 -0.371228
# 14  0.560802  0.358466 -0.256265  0.088283 -0.558631 -0.133778 -0.383550
# 15  0.658949  0.443938 -0.305493  0.177044 -0.118162 -0.155677  0.057504
# 16  0.541753 -0.400157  0.073873 -0.600602 -0.137659  0.058845 -0.073524
# 17 -0.063003  0.081418 -0.223046 -0.151964  0.040012  0.353712  0.047873
# 18  0.929099  0.356815  0.022274  0.049186 -0.094459 -0.052344 -0.081632
# 19  0.503573 -0.260432  0.615104 -0.345661  0.477245  0.316178 -0.074390
#
#        skew.9    skew.10    skew.11    skew.12    skew.13    skew.14  \
# 0   10.000000  11.000000  12.000000  13.000000  14.000000  15.000000
# 1   -0.103560  -0.155110   0.255138  -0.102555   0.034845   0.017370
# 2   -0.087559  -0.173707  -0.031627   0.106064  -0.080311   0.248211
# 3   -0.139368   0.119496   0.025612  -0.173759  -0.047240  -0.257163
# 4   -0.527224   0.056745   0.157576  -0.002260   0.126840   0.058118
# 5   -0.527184   0.139089   0.021101   0.019428  -0.258042  -0.361736
# 6   -0.298943  -0.125543   0.044316   0.056154  -0.125202   0.190158
# 7   -0.075649  -0.181342   0.234700   0.025045   0.065902   0.502970
# 8   -0.053531   0.097517   0.242060  -0.355861  -0.311169   0.323561
# 9   -0.347256   0.018836   0.147133   0.185856   0.075981  -0.001499
# 10  -0.564700  -1.054585  -0.319579  -0.386351   0.131015   0.003308
# 11  -0.182650  -0.118449   0.295796   0.302512   0.315526   0.168689
# 12   0.225109  -0.245301   0.113122  -0.242825  -0.035125   0.339187
# 13  -0.232826   0.529608   0.474634   0.534637   0.648593   0.448676
# 14  -0.341909  -0.351889   0.124415  -0.288012  -0.066996  -0.052982
# 15  -0.283638   0.028651   0.064374  -0.211800  -0.446949   0.024736
# 16   0.150407  -0.170764   0.194575  -0.236218  -0.225997  -0.239412
# 17   0.116747   0.099639   0.276996   0.160198   0.240891   0.039275
# 18  -0.254631  -0.327400  -0.266153   0.237892   0.204583   0.418009
# 19  -0.311001   0.171219   0.092232   0.059010   0.119391   0.073460
#
#       skew.15    skew.16    skew.17    skew.18    skew.19         std  \
# 0   16.000000  17.000000  18.000000  19.000000  20.000000    1.000000
# 1   -0.096178   0.018864  -0.171892   0.067983  -0.151166   97.809044
# 2   -0.040418   0.060530   0.295008   0.209928   0.119846   95.049904
# 3    0.084409   0.002472   0.046101  -0.048907  -0.083755  102.743553
# 4    0.245563  -0.040154   0.148526   0.078542   0.318498  102.515259
# 5   -0.091142  -0.191415   0.178503   0.290319   0.405689  103.415031
# 6   -0.034066   0.159848   0.037765   0.167428   0.165044   67.235062
# 7    0.160429   0.296512   0.516435   0.334011   0.270207  102.937721
# 8   -0.258611  -0.101623   0.107792   0.108116   0.546629   81.842781
# 9    0.329553   0.043023   0.299673   0.602237   0.662522   95.262444
# 10  -0.898446  -0.057608   0.544724  -0.254053   0.722423   87.981544
# 11   0.295805   0.217351   0.197541   0.235425   0.624415   83.339165
# 12  -0.176092  -0.045173   0.127940   0.223609   0.754120   73.861542
# 13   0.256064   0.735482   1.250646   1.061080   1.014946  103.107834
# 14  -0.184654   0.080148   0.687748   1.405741   2.537160   71.316322
# 15  -0.417124   0.008745  -0.133319   0.184710   0.394342   91.573273
# 16  -0.190086  -0.063150  -0.197615  -0.080566   0.282200   88.332962
# 17   0.099628   0.150893   0.254391   0.096408   0.125788  134.252991
# 18   0.588193   0.117660   0.295184   0.256922   0.301573   94.308640
# 19  -0.001189  -0.198837   0.090000  -0.078189   0.140246   94.121193
#
#         std.1      std.2      std.3      std.4      std.5      std.6  \
# 0    2.000000   3.000000   4.000000   5.000000   6.000000   7.000000
# 1   38.569584  22.576273  20.767921  19.869740  20.299164  14.631481
# 2   39.367599  18.873550  24.319347  23.159674  17.159710  13.051704
# 3   44.409843  29.066904  14.013119  15.492754  16.689489  10.712612
# 4   44.471836  27.493378  17.555878  18.756641  14.619661  16.315832
# 5   39.940807  28.944393  23.617382  22.163742  15.855885  13.702240
# 6   30.032679  18.384733  14.685810  17.135206  12.371248  10.572599
# 7   47.479095  28.327360  18.690981  17.260153  13.057912   9.728580
# 8   34.465740  21.773689  18.121128  14.878318  10.592006   8.607622
# 9   47.246140  38.751343  15.224419  13.903268  11.189618   9.624478
# 10  43.896454  17.789066  14.936904  16.872253  10.388876   9.363471
# 11  30.719223  30.598656  20.192095  16.697630  13.612420  11.646677
# 12  40.568790  21.409620  21.147985  19.833809  13.386043  10.552629
# 13  62.303135  33.874454  14.713150  13.694538  10.807119   9.754807
# 14  34.446953  18.490162  15.373009  17.972458  11.212003  11.258093
# 15  41.159988  27.075134  15.559793  16.953527  12.786791  10.897805
# 16  32.495857  29.588789  20.084141  17.097349  18.141926  10.414888
# 17  45.552006  33.449444  25.251865  14.199986  10.257063   8.760317
# 18  54.049675  26.676794  20.572039  14.555149  10.359336   8.505063
# 19  33.682529  22.219500  17.013437  16.935993  12.455042  11.551802
#
#         std.7      std.8      std.9     std.10     std.11     std.12  \
# 0    8.000000   9.000000  10.000000  11.000000  12.000000  13.000000
# 1   12.183411   9.399827  10.742301  10.059609   8.601942   9.284250
# 2   10.914735   9.775167  11.808991   8.863638   9.581952   8.895723
# 3   11.680214   9.722768  11.369185   8.289734   7.985110   7.075400
# 4   10.647793   8.217991  10.194673   9.883532   8.250456   8.085891
# 5   10.210547   9.159851   8.877908   9.464321   8.119837   8.918522
# 6    9.367147   8.418389   8.972911   8.470831   7.663260   7.845415
# 7   10.269384   8.089530   8.252288   7.159144   6.943979   6.900424
# 8    8.864698   6.975258   7.471909   7.343068   7.214496   6.223006
# 9   10.208458   9.268620   8.987002   7.350111   6.293872   6.263802
# 10   9.094247   7.906332   8.094031   7.860756   6.745002   7.395129
# 11  11.704907  10.920756   9.876464  10.390279   9.905450   9.866557
# 12  10.103929   9.543567  10.578824   8.218122   8.670930   7.635729
# 13  10.098685   9.232315   9.383041   7.536267   6.660528   7.851023
# 14   9.252462   8.260457   7.840439   7.565933   7.824467   7.192307
# 15   9.818754   8.870509  10.446862   9.412704   8.233816   6.999366
# 16  16.255989  16.982519  13.641134  14.713183  11.434779  11.130633
# 17  12.034798   9.550224   9.469951   7.223345   8.755466   6.767305
# 18   8.077997   7.406255   7.776560   8.321168   7.162386   6.674051
# 19   9.608631   8.958047   8.621954  10.427566   7.176056   6.349650
#
#        std.13     std.14     std.15     std.16     std.17     std.18  \
# 0   14.000000  15.000000  16.000000  17.000000  18.000000  19.000000
# 1    9.245516   8.520863   8.560472   7.651871   7.246555   7.077188
# 2    8.141456   8.201844   7.780963   7.132692   7.539753   8.452527
# 3    6.972649   7.071393   7.270959   7.051070   6.928591   6.430473
# 4    8.114858   8.832722   8.157245   7.297486   7.734456   7.807103
# 5    8.059117   9.339061   8.451561   8.426965   8.341757   8.572934
# 6    8.043547   8.522350   9.986414   8.932911   9.828950   9.587647
# 7    7.696265   7.003144   7.329900   7.272309   7.059423   6.704741
# 8    6.692973   7.226635   6.434382   6.627854   7.511244   6.966012
# 9    6.564393   7.313915   6.777949   8.136707   8.101400   7.081515
# 10   7.348568   6.917212   7.005051   6.570559   6.871543   7.260060
# 11  10.505244  10.168771  12.910840  11.720415  11.877048  13.942823
# 12   7.754655   9.600611  10.360669   7.952648   8.009152   9.966642
# 13   8.277439   8.385269   8.395930   9.466562   9.733375   8.496548
# 14   7.825604   7.872564   8.317720   6.704911   7.573471   8.832991
# 15   8.021953   8.426239   8.306534   7.507801   8.195595   8.747096
# 16   8.622320   8.076522   7.441574   6.897506   8.454921   7.851885
# 17   7.707868   6.885321   7.027510   8.355102   7.422288   6.848164
# 18   6.240121   6.502113   6.773961   6.559824   6.407545   6.028095
# 19   6.392002   6.018782   5.766465   5.678450   5.579970   6.300434
#
#        std.19    Class
# 0   20.000000      NaN
# 1    7.391859  Hip-Hop
# 2    7.334442  Hip-Hop
# 3    6.186294      Pop
# 4    7.986255     Folk
# 5    9.351485     Folk
# 6    8.106105     Folk
# 7    6.712881     Folk
# 8    8.414756     Folk
# 9    6.618536     Folk
# 10   7.595477     Folk
# 11  12.819324     Folk
# 12   8.899322     Folk
# 13   8.446962     Folk
# 14   9.509195     Folk
# 15   8.979295     Folk
# 16   8.095260     Folk
# 17   6.270457      Pop
# 18   6.224130     Rock
# 19   5.152031     Rock

# %% [markdown]
# ## Utils Function
# - count-digit funtion calculat the count of digit in a number (like 100 have the 3 digits)
# - the purpose of above function is to just for displaying the equal sign qual to the leangth of digits.
#
# - check-shape function count the number of rows and columns in the dataframe
#
# - modelEvaluation function takes the actual labels and predicted labels to calculate the the accuracy, precision, recall and f1-score

# %%
def count_digit(num):
    count = 0
    while num != 0:
        num //= 10
        count += 1
    return count

def check_shape(df):
    rows, cols = df.shape
    print("\nNumber or rows in dataset: {}".format(rows))
    print("==========================={}".format(count_digit(rows)*'='))
    print("\nNumber or columns in dataset: {}".format(cols))
    print("=============================={}".format(count_digit(cols)*'='))
    
def modelEvaluation(predictions, y_test_set, model_name, classes):
    # Print model evaluation to predicted result    
    print("==========",model_name,"==========")
    print ("\nAccuracy on validation set: {:.4f}".format(accuracy_score(y_test_set, predictions)))    
    print ("\nClassification report : \n", classification_report(y_test_set, predictions, target_names = classes))
#     print ("\nConfusion Matrix : \n", confusion_matrix(y_test_set,predictions))
    sns.heatmap(confusion_matrix(y_test_set, predictions),annot=True,yticklabels=classes, xticklabels=classes, fmt='g',cmap='jet')
    
    plt.title('Confusion Matrix of {}'.format(model_name))
    plt.xlabel('predicted Labels')
    plt.ylabel('Actual Labels')
#     plt.tight_layout()
    plt.show()
    results = [accuracy_score(y_test_set, predictions), precision_score(y_test_set, predictions,average='macro'),
              recall_score(y_test_set, predictions,average='macro'),f1_score(y_test_set, predictions,average='macro')]#store results of model
    return results

# %% [markdown]
# # Understand Sample Data
# ## Dataset Samples and Features Count
#
# - display the column names in the dataset
# - display the count of samples in the dataset

# %%
# Understand Sample Data

print("\n\nAttributes in Sample Data:")
print("==========================\n")

print(df1.columns)

print("\n\nNumber of Instances in Sample Data:",len(df1.index))
print("===================================={}\n".format(count_digit(len(df1.index))*'='))
# Out:
# Attributes in Sample Data:
# ==========================
#
# Index(['kurtosis', 'kurtosis.1', 'kurtosis.2', 'kurtosis.3', 'kurtosis.4',
#        'kurtosis.5', 'kurtosis.6', 'kurtosis.7', 'kurtosis.8', 'kurtosis.9',
#        ...
#        'std.11', 'std.12', 'std.13', 'std.14', 'std.15', 'std.16', 'std.17',
#        'std.18', 'std.19', 'Class'],
#       dtype='object', length=141)
#
#
# Number of Instances in Sample Data: 6401
# ========================================

# %% [markdown]
# ## Rename Columns
# - just rename the column

# %%
# rename_column = True
# # column_dict = {"Existing Name": "New Column"}
# column_dict = {"C1": "time", "C2": "label"}

# if rename_column:
#     df = df.rename(columns=column_dict)
    
#     print("\n\nAttributes in Sample Data:")
#     print("==========================\n")
#     print(df.columns)
    
#     print("\n\nSample Data:")
#     print("============\n")
#     print(df.head(2))

# %% [markdown]
# ## Initial Class Distribution
# - check the class distribution in the dataframe.
# - plot the class distribution in bar chat form

# %%
# print(df.label.value_counts(), "\n")

df1['Class'].value_counts()
plt.style.use('ggplot')
df1.value_counts('Class').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Class'>

# %% [markdown]
# - check the class distribution in the dataframe.
# - plot the class distribution in pie chat form

# %%
classes_counts = df1.value_counts('Class')
values = np.array(classes_counts)
mylabels = list(classes_counts.index)

plt.pie(values, labels = mylabels)
plt.legend()
plt.title('Dataset Class Distribution')
# plt.ylabel('Counts')
plt.show()

# %% [markdown]
# # Label Encoding
# - reset index

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
# Encode the values in the 'column' column
df1['Class'] = le.fit_transform(df1['Class'])
df2['Class'] = le.transform(df2['Class'])

# %% [markdown]
# # Feature Extraction
# - remove the samples with Null and NAN values.

# %%
df1 = df1.iloc[1:,:]
df2 = df2.iloc[1:,:]

# %%
features = list(df1.columns[1:])
X_train = df1[features]
y_train = df1['Class']
X_test = df2[features]
y_test = df2['Class']

# %% [markdown]
# - check the shape of the splited sets

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (6399, 140)
# (799, 140)

# %% [markdown]
# - display the class distribution in train and test set

# %% [markdown]
# # Machine Learning
# - extract classes name into classes variable
# - create a distionary to append the results of trained models

# %%
classes = list(df1['Class'].map(int).map(str).unique())
collect_results_of_all_model= {
    'Metrics':['accuracy','precision','recall','f1-score']
} #dic form store results of all models

# %% [markdown]
# ## Logistic Regression
# - import model
# - load model
# - train model with training data
# - make predictionwith trained model on test data

# %%
from sklearn.linear_model import LogisticRegression

lr_classifier = LogisticRegression(random_state=0)
lr_classifier.fit(X_train, y_train)

preds = lr_classifier.predict(X_test)

# %% [markdown]
# - calculate evaluation measures (accuracy, precision, recall, f1-score) using test labels and predicted labels
# - append results into dictionary with the key of model name

# %%
LR_res=modelEvaluation(preds, y_test, 'LR', classes)
collect_results_of_all_model["LR"] = LR_res
# Out:
# ========== LR ==========
#
# Accuracy on validation set: 0.4230
#
# Classification report :
#                precision    recall  f1-score   support
#
#            3       0.50      0.57      0.53       100
#            6       0.38      0.28      0.32       100
#            2       0.13      0.13      0.13       100
#            7       0.62      0.65      0.63       100
#            1       0.51      0.40      0.45       100
#            5       0.37      0.47      0.41       100
#            0       0.30      0.32      0.31       100
#            4       0.57      0.57      0.57        99
#
#     accuracy                           0.42       799
#    macro avg       0.42      0.42      0.42       799
# weighted avg       0.42      0.42      0.42       799

# %% [markdown]
# ## Decision Tree Model
# - import model
# - load model
# - train model with training data
# - make predictionwith trained model on test data

# %%
from sklearn.tree import DecisionTreeClassifier

DT_classifier = DecisionTreeClassifier(random_state=0)
DT_classifier.fit(X_train,y_train)

preds = DT_classifier.predict(X_test)

# %% [markdown]
# ## Desicion Tree Result

# %% [markdown]
# - calculate evaluation measures (accuracy, precision, recall, f1-score) using test labels and predicted labels
# - append results into dictionary with the key of model name

# %%
DT_res=modelEvaluation(preds, y_test, 'DT', classes)
collect_results_of_all_model["DT"] = DT_res
# Out:
# ========== DT ==========
#
# Accuracy on validation set: 1.0000
#
# Classification report :
#                precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00       100
#            6       1.00      1.00      1.00       100
#            2       1.00      1.00      1.00       100
#            7       1.00      1.00      1.00       100
#            1       1.00      1.00      1.00       100
#            5       1.00      1.00      1.00       100
#            0       1.00      1.00      1.00       100
#            4       1.00      1.00      1.00        99
#
#     accuracy                           1.00       799
#    macro avg       1.00      1.00      1.00       799
# weighted avg       1.00      1.00      1.00       799

# %% [markdown]
# ## Random Forest
# - import model
# - load model
# - train model with training data
# - make predictionwith trained model on test data

# %%
from sklearn.ensemble import RandomForestClassifier

RF = RandomForestClassifier(max_depth=5, bootstrap=100)
RF.fit(X_train,y_train)

preds_RF = RF.predict(X_test)

# %% [markdown]
# ## Random Forest Results
# - calculate evaluation measures (accuracy, precision, recall, f1-score) using test labels and predicted labels
# - append results into dictionary with the key of model name

# %%
RF_res = modelEvaluation(preds_RF, y_test, 'Random Forest', classes)
collect_results_of_all_model["RF_CLassifier"] = RF_res
# Out:
# ========== Random Forest ==========
#
# Accuracy on validation set: 0.6521
#
# Classification report :
#                precision    recall  f1-score   support
#
#            3       0.87      0.87      0.87       100
#            6       0.65      0.45      0.53       100
#            2       0.52      0.61      0.56       100
#            7       0.54      0.78      0.64       100
#            1       0.64      0.67      0.66       100
#            5       0.58      0.56      0.57       100
#            0       0.89      0.40      0.55       100
#            4       0.72      0.88      0.79        99
#
#     accuracy                           0.65       799
#    macro avg       0.68      0.65      0.65       799
# weighted avg       0.68      0.65      0.65       799

# %% [markdown]
# ## Naive Bayes
# - import model
# - load model
# - train model with training data
# - make predictionwith trained model on test data

# %%
from sklearn.naive_bayes import GaussianNB

NB_classifier = GaussianNB()
NB_classifier.fit(X_train,y_train)

preds = NB_classifier.predict(X_test)

# %% [markdown]
# ## Naive Bayes Reuslts
# - calculate evaluation measures (accuracy, precision, recall, f1-score) using test labels and predicted labels
# - append results into dictionary with the key of model name

# %%
NB_res=modelEvaluation(preds, y_test, 'NB', classes)
collect_results_of_all_model["NB"] = NB_res
# Out:
# ========== NB ==========
#
# Accuracy on validation set: 1.0000
#
# Classification report :
#                precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00       100
#            6       1.00      1.00      1.00       100
#            2       1.00      1.00      1.00       100
#            7       1.00      1.00      1.00       100
#            1       1.00      1.00      1.00       100
#            5       1.00      1.00      1.00       100
#            0       1.00      1.00      1.00       100
#            4       1.00      1.00      1.00        99
#
#     accuracy                           1.00       799
#    macro avg       1.00      1.00      1.00       799
# weighted avg       1.00      1.00      1.00       799

# %% [markdown]
# ## AdaBoost
# - import model
# - load model
# - train model with training data
# - make predictionwith trained model on test data

# %%
from sklearn.ensemble import AdaBoostClassifier

AB_classifier = AdaBoostClassifier(n_estimators=10, random_state=0)
AB_classifier.fit(X_train,y_train)

preds = AB_classifier.predict(X_test)

# %% [markdown]
# ## AdaBoost Result
# - calculate evaluation measures (accuracy, precision, recall, f1-score) using test labels and predicted labels
# - append results into dictionary with the key of model name

# %%
Ada_res=modelEvaluation(preds, y_test, 'AdaBoot', classes)
collect_results_of_all_model["Ada"] = Ada_res
# Out:
# ========== AdaBoot ==========
#
# Accuracy on validation set: 0.3742
#
# Classification report :
#                precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00       100
#            6       0.17      1.00      0.29       100
#            2       0.00      0.00      0.00       100
#            7       0.00      0.00      0.00       100
#            1       0.00      0.00      0.00       100
#            5       0.00      0.00      0.00       100
#            0       0.00      0.00      0.00       100
#            4       1.00      1.00      1.00        99
#
#     accuracy                           0.37       799
#    macro avg       0.27      0.38      0.29       799
# weighted avg       0.27      0.37      0.28       799

# %% [markdown]
# ## SVM Model

# %%
from sklearn.svm import SVC

SVC_classifier = SVC(max_iter=200)
SVC_classifier.fit(X_train,y_train)

preds = SVC_classifier.predict(X_test)

# %% [markdown]
# ## SVM Results

# %%
SVC_res=modelEvaluation(preds, y_test, 'SVM', classes)
collect_results_of_all_model["SVC"] = SVC_res
# Out:
# ========== SVM ==========
#
# Accuracy on validation set: 0.1577
#
# Classification report :
#                precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00       100
#            6       0.67      0.02      0.04       100
#            2       0.00      0.00      0.00       100
#            7       0.00      0.00      0.00       100
#            1       0.73      0.11      0.19       100
#            5       0.13      0.09      0.11       100
#            0       0.08      0.14      0.11       100
#            4       0.17      0.91      0.29        99
#
#     accuracy                           0.16       799
#    macro avg       0.22      0.16      0.09       799
# weighted avg       0.22      0.16      0.09       799

# %% [markdown]
# ## KNN Model
# - import model
# - load model
# - train model with training data
# - make predictionwith trained model on test data

# %%
from sklearn.neighbors import KNeighborsClassifier

neighbors_clf = KNeighborsClassifier(n_neighbors=5,)
neighbors_clf.fit(X_train,y_train)

KNN_preds = neighbors_clf.predict(X_test)

# %% [markdown]
# ## KNN Results
# - calculate evaluation measures (accuracy, precision, recall, f1-score) using test labels and predicted labels
# - append results into dictionary with the key of model name

# %%
KNN_res = modelEvaluation(KNN_preds,y_test,'KNN',classes)
collect_results_of_all_model["KNN"] = KNN_res
# Out:
# ========== KNN ==========
#
# Accuracy on validation set: 0.3154
#
# Classification report :
#                precision    recall  f1-score   support
#
#            3       0.38      0.45      0.41       100
#            6       0.15      0.13      0.14       100
#            2       0.13      0.15      0.14       100
#            7       0.52      0.59      0.55       100
#            1       0.37      0.29      0.33       100
#            5       0.27      0.29      0.28       100
#            0       0.22      0.18      0.20       100
#            4       0.46      0.44      0.45        99
#
#     accuracy                           0.32       799
#    macro avg       0.31      0.32      0.31       799
# weighted avg       0.31      0.32      0.31       799

# %% [markdown]
# ## Customized NN

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.10, random_state=2)

# %%
# convert target list into categorical list
y_train1 = to_categorical(y_train,num_classes=81)
y_test1 = to_categorical(y_test,num_classes=81)
y_val1 = to_categorical(y_val,num_classes=81)
# display shape of all data sets
print("Shape of y_train",y_train1.shape)
print("Shape of y_test",y_test1.shape)
print("Shape of y_test",y_val1.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20120/3710089509.py in <module>
#       1 # convert target list into categorical list
# ----> 2 y_train1 = to_categorical(y_train,num_classes=81)
#       3 y_test1 = to_categorical(y_test,num_classes=81)
#       4 y_val1 = to_categorical(y_val,num_classes=81)
#       5 # display shape of all data sets
#
# NameError: name 'to_categorical' is not defined

# %%
# model development
model=Sequential()
model.add(Dense(1000,input_dim=5,activation='relu'))
model.add(Dense(500,activation='relu'))
model.add(Dense(300,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(81,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20120/68120395.py in <module>
#       1 # model development
# ----> 2 model=Sequential()
#       3 model.add(Dense(1000,input_dim=5,activation='relu'))
#       4 model.add(Dense(500,activation='relu'))
#       5 model.add(Dense(300,activation='relu'))
#
# NameError: name 'Sequential' is not defined

# %%
# congigure early stopping teachnique
callback = tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=10, min_delta=.001, verbose=True, mode='max')
# fit model
model.fit(X_train,y_train1,validation_data=(X_val,y_val1), batch_size=20,epochs=50,verbose=1, callbacks=[callback])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20120/1582259886.py in <module>
#       1 # congigure early stopping teachnique
# ----> 2 callback = tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=10, min_delta=.001, verbose=True, mode='max')
#       3 # fit model
#       4 model.fit(X_train,y_train1,validation_data=(X_val,y_val1), batch_size=20,epochs=50,verbose=1, callbacks=[callback])
#
# NameError: name 'tf' is not defined

# %%
# make prediction using trained model
predictions = model.predict(X_test)
# calculate accuracy and other evaluation measures
y_pred = [np.argmax(prediction) for prediction in predictions]
# make_predictions(y_test, y_pred)

# %%
KNN_res = modelEvaluation(KNN_preds,y_test,'NN',classes)
collect_results_of_all_model["NN"] = NN_res

# %% [markdown]
# # Rsults Comparison
# ## Comparison Table
# - create dataframe using distionary of model results
# - set the index of dataframe
# - display the dataframe

# %%
# !pip install tabulate
# Out:
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0

# %%
from tabulate import tabulate 
metrics_data_frame = pd.DataFrame(collect_results_of_all_model) # create dataframe
metrics_data_frame = metrics_data_frame.set_index('Metrics') # set index
# displaying the DataFrame
print(tabulate(metrics_data_frame, headers = 'keys', tablefmt = 'psql')) # convert results in to table
# Out:
# +-----------+----------+------+-----------------+------+----------+-----------+----------+
# | Metrics   |       LR |   DT |   RF_CLassifier |   NB |      Ada |       SVC |      KNN |
# |-----------+----------+------+-----------------+------+----------+-----------+----------|
# | accuracy  | 0.423029 |    1 |        0.652065 |    1 | 0.374218 | 0.157697  | 0.315394 |
# | precision | 0.42311  |    1 |        0.675813 |    1 | 0.270833 | 0.223113  | 0.31135  |
# | recall    | 0.423207 |    1 |        0.652348 |    1 | 0.375    | 0.158636  | 0.315556 |
# | f1-score  | 0.420226 |    1 |        0.645867 |    1 | 0.285714 | 0.0910669 | 0.311645 |
# +-----------+----------+------+-----------------+------+----------+-----------+----------+

# %% [markdown]
# - display each row of the above dataframe into a single group
# - in the below bar chat each group showed the accuracy, precision, recall, f1-score respectivelly for each model.

# %%
metrics_data_frame.plot(kind='bar', figsize=(20,10)) # sho comparison base of mertics
plt.xticks(rotation=45, horizontalalignment='right')
plt.title('Comparison Graph')
plt.ylabel('Score')
plt.xlabel("Evaluation Measure")
# Out:
# Text(0.5, 0, 'Evaluation Measure')
