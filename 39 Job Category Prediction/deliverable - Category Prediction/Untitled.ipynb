# %%
import matplotlib.pyplot as plt
import numpy as np

1430
19190
4163
y = np.array([1430, 19190, 4163])
mylabels = ["hate speech", "offensive", "neutral"]
plt.title("")

plt.pie(y, labels = mylabels, autopct='%1.1f%%')
plt.show()

# %%
values = [826, 840, 854]
plt.bar(mylabels, values, color ='maroon',
        width = 0.4)
plt.title("Class Distribution of Tweets in Training Samples")
plt.xlabel("Tweet Class")
plt.ylabel("Tweets Count")
# Out:
# Text(0, 0.5, 'Tweets Count')

# %%
values = [374, 360, 346]
plt.bar(mylabels, values, color ='maroon',
        width = 0.4)
plt.title("Class Distribution of Tweets in Testing Samples")
plt.xlabel("Tweet Class")
plt.ylabel("Tweets Count")
# Out:
# Text(0, 0.5, 'Tweets Count')

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
text = "!!! RT @mayasolovely: As a woman you shouldn't complain about cleaning up your house. &amp; as a man you should always take the trash out..."

# %%
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(text)

# %%
filtered_sentence = [w for w in text if not w.lower() in stop_words]

# %%
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
  
filtered_sentence = []
  
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)
  
print(word_tokens)
print(filtered_sentence)
# Out:
# ['!', '!', '!', 'RT', '@', 'mayasolovely', ':', 'As', 'a', 'woman', 'you', 'should', "n't", 'complain', 'about', 'cleaning', 'up', 'your', 'house', '.', '&', 'amp', ';', 'as', 'a', 'man', 'you', 'should', 'always', 'take', 'the', 'trash', 'out', '...']
# ['!', '!', '!', 'RT', '@', 'mayasolovely', ':', 'As', 'woman', "n't", 'complain', 'cleaning', 'house', '.', '&', 'amp', ';', 'man', 'always', 'take', 'trash', '...']

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
import cv2

# %%
img = cv.imread('wiki.png',0)

# %%
print(img)
# Out:
# None

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7956/1072715444.py in <module>
# ----> 1 opencv-python --version
#
# NameError: name 'opencv' is not defined

# %%
ii = cv.imread('home.jpg',0)

# %%
print(ii)
# Out:
# None

# %%
img_grayscale = cv2.imread('test.jpg',0)
print(img_grayscale)
# Out:
# None
